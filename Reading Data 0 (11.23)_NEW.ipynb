# %%
import requests, zipfile, StringIO
import pandas as pd
from pandas import DataFrame, read_csv
import math
import numpy as np

# %%
urllist=['http://www.census.gov/hhes/www/socdemo/voting/publications/p20/2012/Table04b.csv','http://www.census.gov/hhes/www/socdemo/voting/publications/p20/2010/Table4b_2010.csv', 'http://www.census.gov/hhes/www/socdemo/voting/publications/p20/2008/Table%2004b.csv', 'http://www.census.gov/hhes/www/socdemo/voting/publications/p20/2006/tab04b.csv','http://www.census.gov/hhes/www/socdemo/voting/publications/p20/2004/tab04a.csv', 'http://www.census.gov/hhes/www/socdemo/voting/publications/p20/2002/tab04a.csv']

# %%
for year in [2012, 2010, 2008, 2006, 2004, 2002]:
    url=urllist[(2012-year)/2]
    table=pd.read_csv(StringIO.StringIO(requests.get(url).content),error_bad_lines=False)
    if (year==2012):
        changeCol=dict(zip(table.columns, table.ix[2,:]))#change the columns to match what we want them to be #this portion also not analgous for years
        table.rename(columns=changeCol, inplace=True)
        table=table.drop([0,1,2]).reset_index(drop=True)#ditto this part
        table=table.ix[:,(~pd.isnull(table.columns))] #removing extra nan columns
        stateDictRace=dict(zip([table.ix[11*i,0] for i in range(52)], [table[11*i:11*(i+1)] for i in range(52)]))#dictionary for info on each state 
    elif year==2010:
        changeCol=dict(zip(table.columns, table.ix[1,:]))#change the columns to match what we want them to be #this portion also not analgous for years
        table.rename(columns=changeCol, inplace=True)
        table=table.drop([0,1]).reset_index(drop=True)#ditto this part
        table=table.ix[:, 0:14]
        table.ix[0, 'STATE']='All'
        for i in range(52):
               stateDictRace[table.ix[11*i,0]]=[stateDictRace[table.ix[11*i,0]], table[11*i:11*(i+1)]]
    elif (year==2008)|(year==2006)|(year==2004)|(year==2002):
        table.ix[4,table.columns[0:3]]=table.ix[3,table.columns[0:3]]
        changeCol=dict(zip(table.columns, table.ix[4,:]))#change the columns to match what we want them to be #this portion also not analgous for years
        table.rename(columns=changeCol, inplace=True)
        table=table.drop([0,1,2,3,4]).reset_index(drop=True)#ditto this part
        table=table.ix[:,(~pd.isnull(table.columns))] #removing extra nan columns
        if year==2002:
            for i in range(52):
                table.ix[0, 'STATE']='All'
                existinglist=stateDictRace[table.ix[10*i,0]]
                existinglist.append(table[10*i:10*(i+1)])
                stateDictRace[table.ix[10*i,0]]=existinglist
        else:
            table.ix[0, 'State, sex, race, and Hispanic origin']='All'
        if year==2004:
            table=table.drop([43]).reset_index(drop=True)#one state has a duplicate row
            for i in range(49): #something weird - don't have data for all states in 2004 (missing West Virginia, Wymoning, Wisconsin?)
                existinglist=stateDictRace[table.ix[13*i,0]]
                existinglist.append(table[13*i:13*(i+1)])
                stateDictRace[table.ix[13*i,0]]=existinglist
        elif (year==2006)|(year==2008):
            for i in range(52):
                existinglist=stateDictRace[table.ix[12*i,0]]
                existinglist.append(table[12*i:12*(i+1)])
                stateDictRace[table.ix[12*i,0]]=existinglist
# Out:
# Skipping line 657: expected 13 fields, saw 24
# Skipping line 658: expected 13 fields, saw 24
# Skipping line 659: expected 13 fields, saw 24
# Skipping line 660: expected 13 fields, saw 24
# Skipping line 661: expected 13 fields, saw 24
# Skipping line 662: expected 13 fields, saw 24
# Skipping line 663: expected 13 fields, saw 24
# Skipping line 664: expected 13 fields, saw 24
# Skipping line 665: expected 13 fields, saw 24
# Skipping line 666: expected 13 fields, saw 24
# Skipping line 667: expected 13 fields, saw 24
# Skipping line 668: expected 13 fields, saw 24
# Skipping line 669: expected 13 fields, saw 24
# Skipping line 670: expected 13 fields, saw 24
# Skipping line 671: expected 13 fields, saw 24
# Skipping line 672: expected 13 fields, saw 24
# Skipping line 673: expected 13 fields, saw 37
# Skipping line 674: expected 13 fields, saw 37
# Skipping line 675: expected 13 fields, saw 37
# Skipping line 676: expected 13 fields, saw 37
# Skipping line 677: expected 13 fields, saw 37
# Skipping line 678: expected 13 fields, saw 37
# Skipping line 679: expected 13 fields, saw 37
# Skipping line 680: expected 13 fields, saw 37
# Skipping line 681: expected 13 fields, saw 37
# Skipping line 682: expected 13 fields, saw 37
# Skipping line 683: expected 13 fields, saw 37
# Skipping line 684: expected 13 fields, saw 37
# Skipping line 685: expected 13 fields, saw 37
# Skipping line 686: expected 13 fields, saw 37
# Skipping line 687: expected 13 fields, saw 37
# Skipping line 688: expected 13 fields, saw 37

# %%
def splitbyStateDot(table):
    indices=pd.DataFrame([item[0]=='.' for item in table[table.columns[0]][0:(len(table)-5)]])#trying to find states automatically
    indices=indices.append([False, False, False, False, False]).reset_index(drop=True)
    firstcol=table[table.columns[0]].reset_index(drop=True)
    statesLoc=firstcol[indices[0]==False].index
    return [item for item in firstcol[indices[0]==False]], [table.ix[statesLoc[i]:(statesLoc[i+1]-1), :] for i in range(len(statesLoc)-1)]

# %%
def splitbyStateNull(table):
    indices=table[table.columns[0]].isnull()
    indices[len(indices)-5:len(indices)]=False
    firstcol=table[table.columns[0]]
    statesLoc=firstcol[indices==False].index
    return [item for item in firstcol[indices==False]], [table.ix[statesLoc[i]:(statesLoc[i+1]-1), :] for i in range(len(statesLoc)-1)]

# %%
urllist2=['http://www.census.gov/hhes/www/socdemo/voting/publications/p20/2012/Table04c.csv', 'http://www.census.gov/hhes/www/socdemo/voting/publications/p20/2010/Table4c_2010.csv' ,'http://www.census.gov/hhes/www/socdemo/voting/publications/p20/2008/Table%2004c.csv', 'http://www.census.gov/hhes/www/socdemo/voting/publications/p20/2004/tab04b.csv','http://www.census.gov/hhes/www/socdemo/voting/publications/p20/2002/tab04b.csv']

# %%
for year in [2012, 2010, 2008, 2006, 2004]:
    url=urllist2[(2012-year)/2]
    table=pd.read_csv(StringIO.StringIO(requests.get(url).content),error_bad_lines=False)
    if (year==2012):
        changeCol=dict(zip(table.columns, table.ix[2,:]))#change the columns to match what we want them to be #this portion also not analgous for years
        table.rename(columns=changeCol, inplace=True)
        table=table.drop([0,1,2]).reset_index(drop=True)#ditto this part
        table=table.ix[:,(~pd.isnull(table.columns))] #removing extra nan columns
        states, stateTable=splitbyStateNull(table)
        stateDictAge=dict(zip(states[0:52],stateTable[0:52]))
    elif year==2010:
        table.ix[1, table.columns[1]]=table.ix[2, table.columns[1]]#dealing with nan entry
        changeCol=dict(zip(table.columns, table.ix[1,:]))#change the columns to match what we want them to be #this portion also not analgous for years
        table.rename(columns=changeCol, inplace=True)
        table=table.drop([0,1]).reset_index(drop=True)#ditto this part
        table=table.ix[:,(~pd.isnull(table.columns))] #removing extra nan columns
        states, stateTable=splitbyStateNull(table) 
        for i in range(len(stateDictAge.keys())):
            existinglist=stateDictAge[states[i]]
            existinglist=[existinglist, stateTable[i]]
            stateDictAge[states[i]]=existinglist
    elif (year==2008)|(year==2006)|(year==2004):
        table.ix[4,table.columns[0:3]]=table.ix[3,table.columns[0:3]]
        changeCol=dict(zip(table.columns, table.ix[4,:]))#change the columns to match what we want them to be #this portion also not analgous for years
        table.rename(columns=changeCol, inplace=True)
        table=table.drop([0,1,2,3,4]).reset_index(drop=True)#ditto this part
        table=table.ix[:,(~pd.isnull(table.columns))]#removes null columns
        table=table[~pd.isnull(table[table.columns[0]])]#removes null rows
        table.ix[0, table.columns[0]]='US'
        table2008=table
        states, stateTable=splitbyStateDot(table)
        splitStates=[item.split(' ') for item in states]#removing random 2s in this point
        states=[' '.join([i for i in item if not i.isdigit()]) for item in splitStates]
        for i in range(len(stateDictAge.keys())):
            existinglist=stateDictAge[states[i]]
            existinglist.append(stateTable[i])
            stateDictRace[states[i]]=existinglist
    if year==2006:
        print 'I could not find data for 2006, so this is 2004 instead.'
    if year==2004:
        print 'Similarly, 2004 is actually 2002.'
# Out:
# I could not find data for 2006, so this is 2004 instead.
# Similarly, 2004 is actually 2002.

# %%
stateDictAge['ARKANSAS'][4]
# Out:
#         STATE Population 18 and over Total citizen Percent citizen  \
# 28   ARKANSAS                    NaN           NaN             NaN
# 29     .Total                  1,960         1,919            98.0
# 30  .18 to 24                    223           206            92.4
# 31  .25 to 44                    688           667            96.9
# 32  .45 to 64                    647           645            99.7
# 33  .65 to 74                    206           206           100.0
# 34       .75+                    196           196           100.0
#
#    Confidence interval Total   Percent registered (18+) Confidence interval  \
# 28                 NaN     NaN                      NaN                 NaN
# 29                 0.7   1,222                     62.4                 2.5
# 30                 4.0      71                     31.8                 7.1
# 31                 1.5     391                     56.8                 4.3
# 32                 0.5     443                     68.5                 4.1
# 33                   -     164                     79.4                 6.4
# 34                   -     154                     78.6                 6.6
#
#    Total   Percent voted (18+) Confidence interval
# 28     NaN                 NaN                 NaN
# 29     888                45.3                 2.5
# 30      29                13.0                 5.1
# 31     260                37.8                 4.2
# 32     358                55.3                 4.4
# 33     135                65.4                 7.5
# 34     106                54.2                 8.0

# %%
table
# Out:
#     Table with row headers in column A and column headers in rows 5 through 6.  \
# 0    Table 4b. Reported Voting and Registration of ...
# 1                                       (In thousands)
# 2                      (leading dots indicate subpart)
# 3                                        State and age
# 4                                                  NaN
# 5                                        UNITED STATES
# 6                                               .Total
# 7                                            .18 to 24
# 8                                            .25 to 44
# 9                                            .45 to 64
# 10                                           .65 to 74
# 11                                                .75+
# 12                                             ALABAMA
# 13                                              .Total
# 14                                           .18 to 24
# 15                                           .25 to 44
# 16                                           .45 to 64
# 17                                           .65 to 74
# 18                                                .75+
# 19                                              ALASKA
# 20                                              .Total
# 21                                           .18 to 24
# 22                                           .25 to 44
# 23                                           .45 to 64
# 24                                           .65 to 74
# 25                                                .75+
# 26                                             ARIZONA
# 27                                              .Total
# 28                                           .18 to 24
# 29                                           .25 to 44
# ..                                                 ...
# 396                                                NaN
# 397                                                NaN
# 398                                                NaN
# 399                                                NaN
# 400                                                NaN
# 401                                                NaN
# 402                                                NaN
# 403                                                NaN
# 404                                                NaN
# 405                                                NaN
# 406                                                NaN
# 407                                                NaN
# 408                                                NaN
# 409                                                NaN
# 410                                                NaN
# 411                                                NaN
# 412                                                NaN
# 413                                                NaN
# 414                                                NaN
# 415                                                NaN
# 416                                                NaN
# 417                                                NaN
# 418                                                NaN
# 419                                                NaN
# 420                                                NaN
# 421                                                NaN
# 422                                                NaN
# 423                                                NaN
# 424                                                NaN
# 425                                                NaN
#
#                  Unnamed: 1     Unnamed: 2             Unnamed: 3  \
# 0                       NaN            NaN                    NaN
# 1                       NaN            NaN                    NaN
# 2                       NaN            NaN                    NaN
# 3    Population 18 and over  Total citizen                    NaN
# 4                       NaN        Total    Percent citizen (18+)
# 5                       NaN            NaN                    NaN
# 6                   215,694        197,005                   91.3
# 7                    27,808         24,899                   89.5
# 8                    82,133         71,231                   86.7
# 9                    71,014         67,184                   94.6
# 10                   18,363         17,759                   96.7
# 11                   16,375         15,933                   97.3
# 12                      NaN            NaN                    NaN
# 13                    3,332          3,257                   97.8
# 14                      413            387                   93.7
# 15                    1,223          1,185                   96.9
# 16                    1,131          1,121                   99.1
# 17                      311            311                  100.0
# 18                      254            254                  100.0
# 19                      NaN            NaN                    NaN
# 20                      451            434                   96.2
# 21                       60             58                    (B)
# 22                      178            167                   93.5
# 23                      166            163                   98.2
# 24                       30             30                    (B)
# 25                       18             17                    (B)
# 26                      NaN            NaN                    NaN
# 27                    4,122          3,508                   85.1
# 28                      522            436                   83.4
# 29                    1,616          1,256                   77.8
# ..                      ...            ...                    ...
# 396                     NaN            NaN                    NaN
# 397                     NaN            NaN                    NaN
# 398                     NaN            NaN                    NaN
# 399                     NaN            NaN                    NaN
# 400                     NaN            NaN                    NaN
# 401                     NaN            NaN                    NaN
# 402                     NaN            NaN                    NaN
# 403                     NaN            NaN                    NaN
# 404                     NaN            NaN                    NaN
# 405                     NaN            NaN                    NaN
# 406                     NaN            NaN                    NaN
# 407                     NaN            NaN                    NaN
# 408                     NaN            NaN                    NaN
# 409                     NaN            NaN                    NaN
# 410                     NaN            NaN                    NaN
# 411                     NaN            NaN                    NaN
# 412                     NaN            NaN                    NaN
# 413                     NaN            NaN                    NaN
# 414                     NaN            NaN                    NaN
# 415                     NaN            NaN                    NaN
# 416                     NaN            NaN                    NaN
# 417                     NaN            NaN                    NaN
# 418                     NaN            NaN                    NaN
# 419                     NaN            NaN                    NaN
# 420                     NaN            NaN                    NaN
# 421                     NaN            NaN                    NaN
# 422                     NaN            NaN                    NaN
# 423                     NaN            NaN                    NaN
# 424                     NaN            NaN                    NaN
# 425                     NaN            NaN                    NaN
#
#            Unnamed: 4        Unnamed: 5                Unnamed: 6  \
# 0                 NaN               NaN                       NaN
# 1                 NaN               NaN                       NaN
# 2                 NaN               NaN                       NaN
# 3                 NaN  Total registered                       NaN
# 4    Margin of error1           Total    Percent registered (18+)
# 5                 NaN               NaN                       NaN
# 6                 0.2           142,070                      65.9
# 7                 0.5            14,334                      51.5
# 8                 0.3            49,371                      60.1
# 9                 0.2            51,659                      72.7
# 10                0.4            14,125                      76.9
# 11                0.4            12,581                      76.8
# 12                NaN               NaN                       NaN
# 13                0.7             2,418                      72.6
# 14                3.3               211                      51.1
# 15                1.4               832                      68.1
# 16                0.8               888                      78.5
# 17                  -               284                      91.3
# 18                  -               203                      79.9
# 19                NaN               NaN                       NaN
# 20                0.9               334                      74.0
# 21                (B)                37                       (B)
# 22                1.8               125                      70.5
# 23                1.0               135                      81.4
# 24                (B)                23                       (B)
# 25                (B)                13                       (B)
# 26                NaN               NaN                       NaN
# 27                1.7             2,485                      60.3
# 28                4.9               249                      47.8
# 29                3.1               819                      50.7
# ..                ...               ...                       ...
# 396               NaN               NaN                       NaN
# 397               NaN               NaN                       NaN
# 398               NaN               NaN                       NaN
# 399               NaN               NaN                       NaN
# 400               NaN               NaN                       NaN
# 401               NaN               NaN                       NaN
# 402               NaN               NaN                       NaN
# 403               NaN               NaN                       NaN
# 404               NaN               NaN                       NaN
# 405               NaN               NaN                       NaN
# 406               NaN               NaN                       NaN
# 407               NaN               NaN                       NaN
# 408               NaN               NaN                       NaN
# 409               NaN               NaN                       NaN
# 410               NaN               NaN                       NaN
# 411               NaN               NaN                       NaN
# 412               NaN               NaN                       NaN
# 413               NaN               NaN                       NaN
# 414               NaN               NaN                       NaN
# 415               NaN               NaN                       NaN
# 416               NaN               NaN                       NaN
# 417               NaN               NaN                       NaN
# 418               NaN               NaN                       NaN
# 419               NaN               NaN                       NaN
# 420               NaN               NaN                       NaN
# 421               NaN               NaN                       NaN
# 422               NaN               NaN                       NaN
# 423               NaN               NaN                       NaN
# 424               NaN               NaN                       NaN
# 425               NaN               NaN                       NaN
#
#            Unnamed: 7   Unnamed: 8           Unnamed: 9       Unnamed: 10  \
# 0                 NaN          NaN                  NaN               NaN
# 1                 NaN          NaN                  NaN               NaN
# 2                 NaN          NaN                  NaN               NaN
# 3                 NaN  Total voted                  NaN               NaN
# 4    Margin of error1      Total    Percent voted (18+)  Margin of error1
# 5                 NaN          NaN                  NaN               NaN
# 6                 0.3      125,736                 58.3               0.3
# 7                 0.8       11,639                 41.9               0.8
# 8                 0.5       42,845                 52.2               0.5
# 9                 0.5       47,327                 66.6               0.5
# 10                0.9       13,010                 70.8               0.9
# 11                0.9       10,915                 66.7               1.0
# 12                NaN          NaN                  NaN               NaN
# 13                2.1        2,060                 61.8               2.3
# 14                6.7          173                 42.0               6.6
# 15                3.6          685                 56.0               3.9
# 16                3.3          797                 70.5               3.7
# 17                4.4          247                 79.2               6.3
# 18                6.9          158                 62.2               8.3
# 19                NaN          NaN                  NaN               NaN
# 20                2.0          293                 65.0               2.2
# 21                (B)           31                  (B)               (B)
# 22                3.3          107                 60.2               3.6
# 23                3.0          122                 73.8               3.3
# 24                (B)           22                  (B)               (B)
# 25                (B)           11                  (B)               (B)
# 26                NaN          NaN                  NaN               NaN
# 27                2.3        2,239                 54.3               2.3
# 28                6.6          184                 35.2               6.3
# 29                3.8          708                 43.8               3.7
# ..                ...          ...                  ...               ...
# 396               NaN          NaN                  NaN               NaN
# 397               NaN          NaN                  NaN               NaN
# 398               NaN          NaN                  NaN               NaN
# 399               NaN          NaN                  NaN               NaN
# 400               NaN          NaN                  NaN               NaN
# 401               NaN          NaN                  NaN               NaN
# 402               NaN          NaN                  NaN               NaN
# 403               NaN          NaN                  NaN               NaN
# 404               NaN          NaN                  NaN               NaN
# 405               NaN          NaN                  NaN               NaN
# 406               NaN          NaN                  NaN               NaN
# 407               NaN          NaN                  NaN               NaN
# 408               NaN          NaN                  NaN               NaN
# 409               NaN          NaN                  NaN               NaN
# 410               NaN          NaN                  NaN               NaN
# 411               NaN          NaN                  NaN               NaN
# 412               NaN          NaN                  NaN               NaN
# 413               NaN          NaN                  NaN               NaN
# 414               NaN          NaN                  NaN               NaN
# 415               NaN          NaN                  NaN               NaN
# 416               NaN          NaN                  NaN               NaN
# 417               NaN          NaN                  NaN               NaN
# 418               NaN          NaN                  NaN               NaN
# 419               NaN          NaN                  NaN               NaN
# 420               NaN          NaN                  NaN               NaN
# 421               NaN          NaN                  NaN               NaN
# 422               NaN          NaN                  NaN               NaN
# 423               NaN          NaN                  NaN               NaN
# 424               NaN          NaN                  NaN               NaN
# 425               NaN          NaN                  NaN               NaN
#
#      Unnamed: 11  Unnamed: 12
# 0            NaN          NaN
# 1            NaN          NaN
# 2            NaN          NaN
# 3            NaN          NaN
# 4            NaN          NaN
# 5            NaN          NaN
# 6            NaN          NaN
# 7            NaN          NaN
# 8            NaN          NaN
# 9            NaN          NaN
# 10           NaN          NaN
# 11           NaN          NaN
# 12           NaN          NaN
# 13           NaN          NaN
# 14           NaN          NaN
# 15           NaN          NaN
# 16           NaN          NaN
# 17           NaN          NaN
# 18           NaN          NaN
# 19           NaN          NaN
# 20           NaN          NaN
# 21           NaN          NaN
# 22           NaN          NaN
# 23           NaN          NaN
# 24           NaN          NaN
# 25           NaN          NaN
# 26           NaN          NaN
# 27           NaN          NaN
# 28           NaN          NaN
# 29           NaN          NaN
# ..           ...          ...
# 396          NaN          NaN
# 397          NaN          NaN
# 398          NaN          NaN
# 399          NaN          NaN
# 400          NaN          NaN
# 401          NaN          NaN
# 402          NaN          NaN
# 403          NaN          NaN
# 404          NaN          NaN
# 405          NaN          NaN
# 406          NaN          NaN
# 407          NaN          NaN
# 408          NaN          NaN
# 409          NaN          NaN
# 410          NaN          NaN
# 411          NaN          NaN
# 412          NaN          NaN
# 413          NaN          NaN
# 414          NaN          NaN
# 415          NaN          NaN
# 416          NaN          NaN
# 417          NaN          NaN
# 418          NaN          NaN
# 419          NaN          NaN
# 420          NaN          NaN
# 421          NaN          NaN
# 422          NaN          NaN
# 423          NaN          NaN
# 424          NaN          NaN
# 425          NaN          NaN
#
# [426 rows x 13 columns]

# %%
# Out:
# Int64Index([0, 9, 16, 21, 28, 35, 42, 49, 56, 61, 66, 73, 80, 87, 92, 99, 106, 113, 120, 127, 134, 141, 148, 155, 162, 169, 176, 183, 188, 195, 202, 209, 216, 223, 230, 237, 242, 249, 256, 263, 270, 275, 282, 287, 294, 301, 308, 313, 320, 327, 334, 341, 346, 347, 348, 349, 350, 351], dtype='int64')

# %%
changeCol=dict(zip(table.columns, table.ix[2,:]))#change the columns to match what we want them to be #this portion also not analgous for years
table.rename(columns=changeCol, inplace=True)
table=table.drop([0,1,2]).reset_index(drop=True)#ditto this part
table=table.ix[:,(~pd.isnull(table.columns))] #removing extra nan columns

# %%
table
# Out:
#                                                  STATE Population 18 and over  \
# 0                                                  All                    NaN
# 1                                               .Total                210,421
# 2                                                .Male                100,939
# 3                                              .Female                109,481
# 4                                  .Non-Hispanic White                105,499
# 5                                  .Non-Hispanic Black                 23,556
# 6                          .Asian and Pacific Islander                  9,631
# 7                              .Hispanic (of any race)                 25,162
# 8                                               .White                174,099
# 9                                               .Black                 24,445
# 10                                             ALABAMA
# 11                                              .Total                  3,252
# 12                                               .Male                  1,520
# 13                                             .Female                  1,732
# 14                                 .Non-Hispanic White                  2,421
# 15                                 .Non-Hispanic Black                    776
# 16                         .Asian and Pacific Islander                     23
# 17                             .Hispanic (of any race)                     30
# 18                                              .White                  2,452
# 19                                              .Black                    776
# 20                                              ALASKA                    NaN
# 21                                              .Total                    437
# 22                                               .Male                    220
# 23                                             .Female                    217
# 24                                 .Non-Hispanic White                    318
# 25                                 .Non-Hispanic Black                     10
# 26                         .Asian and Pacific Islander                     28
# 27                             .Hispanic (of any race)                     20
# 28                                              .White                    333
# 29                                              .Black                     13
# ..                                                 ...                    ...
# 496                        .Asian and Pacific Islander                      6
# 497                            .Hispanic (of any race)                      8
# 498                                             .White                  1,334
# 499                                             .Black                     34
# 500                                          WISCONSIN                    NaN
# 501                                             .Total                  4,119
# 502                                              .Male                  2,073
# 503                                            .Female                  2,045
# 504                                .Non-Hispanic White                  3,622
# 505                                .Non-Hispanic Black                    167
# 506                        .Asian and Pacific Islander                     85
# 507                            .Hispanic (of any race)                    201
# 508                                             .White                  3,801
# 509                                             .Black                    184
# 510                                            WYOMING                    NaN
# 511                                             .Total                    370
# 512                                              .Male                    179
# 513                                            .Female                    191
# 514                                .Non-Hispanic White                    338
# 515                                .Non-Hispanic Black                      3
# 516                        .Asian and Pacific Islander                      2
# 517                            .Hispanic (of any race)                     19
# 518                                             .White                    356
# 519                                             .Black                      3
# 520                                         Footnotes:                    NaN
# 521  Note: The symbol (B) means that the base is to...                    NaN
# 522     Note: " - " Represents zero or rounds to zero.                    NaN
# 523                                                NaN                    NaN
# 524  Source: U.S. Census Bureau, Current Population...                    NaN
# 525              Internet Release date:  July 28, 2004                    NaN
#
#     Total citizen Percent citizen Confidence interval  Total    \
# 0             NaN             NaN                 NaN      NaN
# 1         192,656            91.6                 0.2  128,154
# 2          91,644            90.8                 0.3   59,422
# 3         101,012            92.3                 0.2   68,732
# 4         147,171            97.8                 0.1  102,154
# 5          22,289            94.6                 0.5   13,976
# 6           6,008            62.4                 1.8    2,955
# 7          15,601            62.0                 1.4    8,196
# 8         161,694            92.9                 0.2  109,808
# 9          22,912            93.7                 0.5   14,304
# 10            NaN             NaN                 NaN      NaN
# 11          3,215            98.9                 0.5    2,347
# 12          1,503            98.9                 0.7    1,059
# 13          1,712            98.8                 0.7    1,288
# 14          2,402            99.2                 0.5    1,798
# 15            776           100.0                   -      524
# 16             18             (B)                 (B)       13
# 17             17             (B)                 (B)       10
# 18          2,419            98.7                 0.6    1,807
# 19            776           100.0                   -      524
# 20            NaN             NaN                 NaN      NaN
# 21            418            95.7                 1.0      303
# 22            212            96.4                 1.2      152
# 23            206            94.9                 1.5      151
# 24            313            98.4                 0.7      237
# 25             10             (B)                 (B)        4
# 26             20             (B)                 (B)       12
# 27             15             (B)                 (B)       11
# 28            325            97.7                 0.8      246
# 29             11             (B)                 (B)        5
# ..            ...             ...                 ...      ...
# 496             4             (B)                 (B)        -
# 497             8             (B)                 (B)        5
# 498         1,331            99.8                 0.2      810
# 499            33             (B)                 (B)       15
# 500           NaN             NaN                 NaN      NaN
# 501         3,975            96.5                 0.7    2,744
# 502         1,992            96.1                 1.1    1,360
# 503         1,982            96.9                 1.0    1,383
# 504         3,610            99.7                 0.2    2,650
# 505           165            98.6                 2.8       95
# 506            44             (B)                 (B)       22
# 507           113            56.2                14.1       51
# 508         3,715            97.7                 0.6    2,605
# 509           171            93.1                 5.8      101
# 510           NaN             NaN                 NaN      NaN
# 511           368            99.5                 0.3      240
# 512           178            99.6                 0.4      113
# 513           190            99.3                 0.5      127
# 514           337            99.8                 0.2      225
# 515             3             (B)                 (B)        -
# 516             2             (B)                 (B)        -
# 517            18             (B)                 (B)       10
# 518           354            99.4                 0.4      234
# 519             3             (B)                 (B)        -
# 520           NaN             NaN                 NaN      NaN
# 521           NaN             NaN                 NaN      NaN
# 522           NaN             NaN                 NaN      NaN
# 523           NaN             NaN                 NaN      NaN
# 524           NaN             NaN                 NaN      NaN
# 525           NaN             NaN                 NaN      NaN
#
#     Percent registered (18+) Confidence interval Total   Percent voted (18+)  \
# 0                        NaN                 NaN     NaN                 NaN
# 1                       60.9                 0.3  88,903                42.3
# 2                       58.9                 0.4  41,801                41.4
# 3                       62.8                 0.4  47,102                43.0
# 4                       67.9                 0.3  72,259                48.0
# 5                       59.3                 1.1   9,522                40.4
# 6                       30.7                 1.7   1,873                19.4
# 7                       32.6                 1.3   4,747                18.9
# 8                       63.1                 0.3  76,730                44.1
# 9                       58.5                 1.1   9,695                39.7
# 10                       NaN                 NaN     NaN                 NaN
# 11                      72.2                 2.2   1,585                48.7
# 12                      69.6                 3.2     755                49.7
# 13                      74.4                 2.9     829                47.9
# 14                      74.2                 2.4   1,242                51.3
# 15                      67.6                 5.6     336                43.3
# 16                       (B)                 (B)       6                 (B)
# 17                       (B)                 (B)       -                 (B)
# 18                      73.7                 2.4   1,242                50.7
# 19                      67.6                 5.6     336                43.3
# 20                       NaN                 NaN     NaN                 NaN
# 21                      69.4                 2.2     230                52.6
# 22                      69.2                 3.0     111                50.7
# 23                      69.6                 3.1     118                54.5
# 24                      74.6                 2.4     184                57.8
# 25                       (B)                 (B)       3                 (B)
# 26                       (B)                 (B)       8                 (B)
# 27                       (B)                 (B)       8                 (B)
# 28                      73.9                 2.4     190                57.1
# 29                       (B)                 (B)       3                 (B)
# ..                       ...                 ...     ...                 ...
# 496                      (B)                 (B)       -                 (B)
# 497                      (B)                 (B)       3                 (B)
# 498                     60.8                 2.2     495                37.1
# 499                      (B)                 (B)      10                 (B)
# 500                      NaN                 NaN     NaN                 NaN
# 501                     66.6                 1.9   1,999                48.5
# 502                     65.6                 2.7   1,005                48.5
# 503                     67.6                 2.6     994                48.6
# 504                     70.7                 1.9   1,887                52.1
# 505                     56.8                11.9      68                40.6
# 506                      (B)                 (B)      13                 (B)
# 507                     25.3                12.3      20                10.0
# 508                     68.5                 1.9   1,905                50.1
# 509                     54.9                11.4      70                38.3
# 510                      NaN                 NaN     NaN                 NaN
# 511                     64.9                 2.2     198                53.6
# 512                     63.1                 3.2      92                51.5
# 513                     66.6                 3.0     106                55.6
# 514                     66.7                 2.3     188                55.6
# 515                      (B)                 (B)       -                 (B)
# 516                      (B)                 (B)       -                 (B)
# 517                      (B)                 (B)       7                 (B)
# 518                     65.6                 2.2     195                54.6
# 519                      (B)                 (B)       -                 (B)
# 520                      NaN                 NaN     NaN                 NaN
# 521                      NaN                 NaN     NaN                 NaN
# 522                      NaN                 NaN     NaN                 NaN
# 523                      NaN                 NaN     NaN                 NaN
# 524                      NaN                 NaN     NaN                 NaN
# 525                      NaN                 NaN     NaN                 NaN
#
#     Confidence interval
# 0                   NaN
# 1                   0.3
# 2                   0.4
# 3                   0.4
# 4                   0.4
# 5                   1.1
# 6                   1.4
# 7                   1.1
# 8                   0.3
# 9                   1.1
# 10                  NaN
# 11                  2.4
# 12                  3.5
# 13                  3.3
# 14                  2.8
# 15                  5.9
# 16                  (B)
# 17                  (B)
# 18                  2.8
# 19                  5.9
# 20                  NaN
# 21                  2.3
# 22                  3.3
# 23                  3.3
# 24                  2.7
# 25                  (B)
# 26                  (B)
# 27                  (B)
# 28                  2.6
# 29                  (B)
# ..                  ...
# 496                 (B)
# 497                 (B)
# 498                 2.2
# 499                 (B)
# 500                 NaN
# 501                 2.0
# 502                 2.8
# 503                 2.8
# 504                 2.1
# 505                11.7
# 506                 (B)
# 507                 8.5
# 508                 2.1
# 509                11.1
# 510                 NaN
# 511                 2.3
# 512                 3.3
# 513                 3.2
# 514                 2.4
# 515                 (B)
# 516                 (B)
# 517                 (B)
# 518                 2.4
# 519                 (B)
# 520                 NaN
# 521                 NaN
# 522                 NaN
# 523                 NaN
# 524                 NaN
# 525                 NaN
#
# [526 rows x 11 columns]

# %%
#Note: I found how many non-nan entries there were with (~pd.isnull(table['State'])).sum() 
for item in stateDict.keys():
    if len(stateDict[item])<5:
        print item
# Out:
# WEST VIRGINIA
# WYOMING
# WISCONSIN

# %%
table2002
# Out:
#                                                  STATE Population 18 and over  \
# 0                                        UNITED STATES                    NaN
# 1                                               .Total                210,421
# 2                                                .Male                100,939
# 3                                              .Female                109,481
# 4                                  .Non-Hispanic White                105,499
# 5                                  .Non-Hispanic Black                 23,556
# 6                          .Asian and Pacific Islander                  9,631
# 7                              .Hispanic (of any race)                 25,162
# 8                                               .White                174,099
# 9                                               .Black                 24,445
# 10                                             ALABAMA
# 11                                              .Total                  3,252
# 12                                               .Male                  1,520
# 13                                             .Female                  1,732
# 14                                 .Non-Hispanic White                  2,421
# 15                                 .Non-Hispanic Black                    776
# 16                         .Asian and Pacific Islander                     23
# 17                             .Hispanic (of any race)                     30
# 18                                              .White                  2,452
# 19                                              .Black                    776
# 20                                              ALASKA                    NaN
# 21                                              .Total                    437
# 22                                               .Male                    220
# 23                                             .Female                    217
# 24                                 .Non-Hispanic White                    318
# 25                                 .Non-Hispanic Black                     10
# 26                         .Asian and Pacific Islander                     28
# 27                             .Hispanic (of any race)                     20
# 28                                              .White                    333
# 29                                              .Black                     13
# ..                                                 ...                    ...
# 496                        .Asian and Pacific Islander                      6
# 497                            .Hispanic (of any race)                      8
# 498                                             .White                  1,334
# 499                                             .Black                     34
# 500                                          WISCONSIN                    NaN
# 501                                             .Total                  4,119
# 502                                              .Male                  2,073
# 503                                            .Female                  2,045
# 504                                .Non-Hispanic White                  3,622
# 505                                .Non-Hispanic Black                    167
# 506                        .Asian and Pacific Islander                     85
# 507                            .Hispanic (of any race)                    201
# 508                                             .White                  3,801
# 509                                             .Black                    184
# 510                                            WYOMING                    NaN
# 511                                             .Total                    370
# 512                                              .Male                    179
# 513                                            .Female                    191
# 514                                .Non-Hispanic White                    338
# 515                                .Non-Hispanic Black                      3
# 516                        .Asian and Pacific Islander                      2
# 517                            .Hispanic (of any race)                     19
# 518                                             .White                    356
# 519                                             .Black                      3
# 520                                         Footnotes:                    NaN
# 521  Note: The symbol (B) means that the base is to...                    NaN
# 522     Note: " - " Represents zero or rounds to zero.                    NaN
# 523                                                NaN                    NaN
# 524  Source: U.S. Census Bureau, Current Population...                    NaN
# 525              Internet Release date:  July 28, 2004                    NaN
#
#     Total citizen Percent citizen Confidence interval  Total    \
# 0             NaN             NaN                 NaN      NaN
# 1         192,656            91.6                 0.2  128,154
# 2          91,644            90.8                 0.3   59,422
# 3         101,012            92.3                 0.2   68,732
# 4         147,171            97.8                 0.1  102,154
# 5          22,289            94.6                 0.5   13,976
# 6           6,008            62.4                 1.8    2,955
# 7          15,601            62.0                 1.4    8,196
# 8         161,694            92.9                 0.2  109,808
# 9          22,912            93.7                 0.5   14,304
# 10            NaN             NaN                 NaN      NaN
# 11          3,215            98.9                 0.5    2,347
# 12          1,503            98.9                 0.7    1,059
# 13          1,712            98.8                 0.7    1,288
# 14          2,402            99.2                 0.5    1,798
# 15            776           100.0                   -      524
# 16             18             (B)                 (B)       13
# 17             17             (B)                 (B)       10
# 18          2,419            98.7                 0.6    1,807
# 19            776           100.0                   -      524
# 20            NaN             NaN                 NaN      NaN
# 21            418            95.7                 1.0      303
# 22            212            96.4                 1.2      152
# 23            206            94.9                 1.5      151
# 24            313            98.4                 0.7      237
# 25             10             (B)                 (B)        4
# 26             20             (B)                 (B)       12
# 27             15             (B)                 (B)       11
# 28            325            97.7                 0.8      246
# 29             11             (B)                 (B)        5
# ..            ...             ...                 ...      ...
# 496             4             (B)                 (B)        -
# 497             8             (B)                 (B)        5
# 498         1,331            99.8                 0.2      810
# 499            33             (B)                 (B)       15
# 500           NaN             NaN                 NaN      NaN
# 501         3,975            96.5                 0.7    2,744
# 502         1,992            96.1                 1.1    1,360
# 503         1,982            96.9                 1.0    1,383
# 504         3,610            99.7                 0.2    2,650
# 505           165            98.6                 2.8       95
# 506            44             (B)                 (B)       22
# 507           113            56.2                14.1       51
# 508         3,715            97.7                 0.6    2,605
# 509           171            93.1                 5.8      101
# 510           NaN             NaN                 NaN      NaN
# 511           368            99.5                 0.3      240
# 512           178            99.6                 0.4      113
# 513           190            99.3                 0.5      127
# 514           337            99.8                 0.2      225
# 515             3             (B)                 (B)        -
# 516             2             (B)                 (B)        -
# 517            18             (B)                 (B)       10
# 518           354            99.4                 0.4      234
# 519             3             (B)                 (B)        -
# 520           NaN             NaN                 NaN      NaN
# 521           NaN             NaN                 NaN      NaN
# 522           NaN             NaN                 NaN      NaN
# 523           NaN             NaN                 NaN      NaN
# 524           NaN             NaN                 NaN      NaN
# 525           NaN             NaN                 NaN      NaN
#
#     Percent registered (18+) Confidence interval Total   Percent voted (18+)  \
# 0                        NaN                 NaN     NaN                 NaN
# 1                       60.9                 0.3  88,903                42.3
# 2                       58.9                 0.4  41,801                41.4
# 3                       62.8                 0.4  47,102                43.0
# 4                       67.9                 0.3  72,259                48.0
# 5                       59.3                 1.1   9,522                40.4
# 6                       30.7                 1.7   1,873                19.4
# 7                       32.6                 1.3   4,747                18.9
# 8                       63.1                 0.3  76,730                44.1
# 9                       58.5                 1.1   9,695                39.7
# 10                       NaN                 NaN     NaN                 NaN
# 11                      72.2                 2.2   1,585                48.7
# 12                      69.6                 3.2     755                49.7
# 13                      74.4                 2.9     829                47.9
# 14                      74.2                 2.4   1,242                51.3
# 15                      67.6                 5.6     336                43.3
# 16                       (B)                 (B)       6                 (B)
# 17                       (B)                 (B)       -                 (B)
# 18                      73.7                 2.4   1,242                50.7
# 19                      67.6                 5.6     336                43.3
# 20                       NaN                 NaN     NaN                 NaN
# 21                      69.4                 2.2     230                52.6
# 22                      69.2                 3.0     111                50.7
# 23                      69.6                 3.1     118                54.5
# 24                      74.6                 2.4     184                57.8
# 25                       (B)                 (B)       3                 (B)
# 26                       (B)                 (B)       8                 (B)
# 27                       (B)                 (B)       8                 (B)
# 28                      73.9                 2.4     190                57.1
# 29                       (B)                 (B)       3                 (B)
# ..                       ...                 ...     ...                 ...
# 496                      (B)                 (B)       -                 (B)
# 497                      (B)                 (B)       3                 (B)
# 498                     60.8                 2.2     495                37.1
# 499                      (B)                 (B)      10                 (B)
# 500                      NaN                 NaN     NaN                 NaN
# 501                     66.6                 1.9   1,999                48.5
# 502                     65.6                 2.7   1,005                48.5
# 503                     67.6                 2.6     994                48.6
# 504                     70.7                 1.9   1,887                52.1
# 505                     56.8                11.9      68                40.6
# 506                      (B)                 (B)      13                 (B)
# 507                     25.3                12.3      20                10.0
# 508                     68.5                 1.9   1,905                50.1
# 509                     54.9                11.4      70                38.3
# 510                      NaN                 NaN     NaN                 NaN
# 511                     64.9                 2.2     198                53.6
# 512                     63.1                 3.2      92                51.5
# 513                     66.6                 3.0     106                55.6
# 514                     66.7                 2.3     188                55.6
# 515                      (B)                 (B)       -                 (B)
# 516                      (B)                 (B)       -                 (B)
# 517                      (B)                 (B)       7                 (B)
# 518                     65.6                 2.2     195                54.6
# 519                      (B)                 (B)       -                 (B)
# 520                      NaN                 NaN     NaN                 NaN
# 521                      NaN                 NaN     NaN                 NaN
# 522                      NaN                 NaN     NaN                 NaN
# 523                      NaN                 NaN     NaN                 NaN
# 524                      NaN                 NaN     NaN                 NaN
# 525                      NaN                 NaN     NaN                 NaN
#
#     Confidence interval
# 0                   NaN
# 1                   0.3
# 2                   0.4
# 3                   0.4
# 4                   0.4
# 5                   1.1
# 6                   1.4
# 7                   1.1
# 8                   0.3
# 9                   1.1
# 10                  NaN
# 11                  2.4
# 12                  3.5
# 13                  3.3
# 14                  2.8
# 15                  5.9
# 16                  (B)
# 17                  (B)
# 18                  2.8
# 19                  5.9
# 20                  NaN
# 21                  2.3
# 22                  3.3
# 23                  3.3
# 24                  2.7
# 25                  (B)
# 26                  (B)
# 27                  (B)
# 28                  2.6
# 29                  (B)
# ..                  ...
# 496                 (B)
# 497                 (B)
# 498                 2.2
# 499                 (B)
# 500                 NaN
# 501                 2.0
# 502                 2.8
# 503                 2.8
# 504                 2.1
# 505                11.7
# 506                 (B)
# 507                 8.5
# 508                 2.1
# 509                11.1
# 510                 NaN
# 511                 2.3
# 512                 3.3
# 513                 3.2
# 514                 2.4
# 515                 (B)
# 516                 (B)
# 517                 (B)
# 518                 2.4
# 519                 (B)
# 520                 NaN
# 521                 NaN
# 522                 NaN
# 523                 NaN
# 524                 NaN
# 525                 NaN
#
# [526 rows x 11 columns]

# %%
count=0
for i in range(52):
    print table2002.ix[10*i,0], count
    count=count+1
# Out:
# UNITED STATES 0
# ALABAMA 1
# ALASKA 2
# ARIZONA 3
# ARKANSAS 4
# CALIFORNIA 5
# COLORADO 6
# CONNECTICUT 7
# DELAWARE 8
# DISTRICT OF COLUMBIA 9
# FLORIDA 10
# GEORGIA 11
# HAWAII 12
# IDAHO 13
# ILLINOIS 14
# INDIANA 15
# IOWA 16
# KANSAS 17
# KENTUCKY 18
# LOUISIANA 19
# MAINE 20
# MARYLAND 21
# MASSACHUSETTS 22
# MICHIGAN 23
# MINNESOTA 24
# MISSISSIPPI 25
# MISSOURI 26
# MONTANA 27
# NEBRASKA 28
# NEVADA 29
# NEW HAMPSHIRE 30
# NEW JERSEY 31
# NEW MEXICO 32
# NEW YORK 33
# NORTH CAROLINA 34
# NORTH DAKOTA 35
# OHIO 36
# OKLAHOMA 37
# OREGON 38
# PENNSYLVANIA 39
# RHODE ISLAND 40
# SOUTH CAROLINA 41
# SOUTH DAKOTA 42
# TENNESSEE 43
# TEXAS 44
# UTAH 45
# VERMONT 46
# VIRGINIA 47
# WASHINGTON
#  48
# WEST VIRGINIA 49
# WISCONSIN 50
# WYOMING 51

# %%
table[table.columns[0]][0:(len(table)-5)]
# Out:
# 0                             All
# 1                          .Total
# 2                           .Male
# 3                         .Female
# 4             .Non-Hispanic White
# 5             .Non-Hispanic Black
# 6     .Asian and Pacific Islander
# 7         .Hispanic (of any race)
# 8                          .White
# 9                          .Black
# 10                        ALABAMA
# 11                         .Total
# 12                          .Male
# 13                        .Female
# 14            .Non-Hispanic White
# ...
# 506    .Asian and Pacific Islander
# 507        .Hispanic (of any race)
# 508                         .White
# 509                         .Black
# 510                        WYOMING
# 511                         .Total
# 512                          .Male
# 513                        .Female
# 514            .Non-Hispanic White
# 515            .Non-Hispanic Black
# 516    .Asian and Pacific Islander
# 517        .Hispanic (of any race)
# 518                         .White
# 519                         .Black
# 520                     Footnotes:
# Name: STATE, Length: 521, dtype: object

# %%
indices=pd.DataFrame([item[0]=='.' for item in table[table.columns[0]][0:(len(table)-5)]])#trying to find states automatically
indices=indices.append([False, False, False, False, False]).reset_index(drop=True)
firstcol=table[table.columns[0]]
statesLoc=firstcol[indices[0]==False].index
[item for item in firstcol[indices[0]==False]]
[table.ix[statesLoc[i]:(statesLoc[i+1]-1), :] for i in range(len(statesLoc)-1)]
# Out:
# ['All',
#  'ALABAMA',
#  'ALASKA',
#  'ARIZONA',
#  'ARKANSAS',
#  'CALIFORNIA',
#  'COLORADO',
#  'CONNECTICUT',
#  'DELAWARE',
#  'DISTRICT OF COLUMBIA',
#  'FLORIDA',
#  'GEORGIA',
#  'HAWAII',
#  'IDAHO',
#  'ILLINOIS',
#  'INDIANA',
#  'IOWA',
#  'KANSAS',
#  'KENTUCKY',
#  'LOUISIANA',
#  'MAINE',
#  'MARYLAND',
#  'MASSACHUSETTS',
#  'MICHIGAN',
#  'MINNESOTA',
#  'MISSISSIPPI',
#  'MISSOURI',
#  'MONTANA',
#  'NEBRASKA',
#  'NEVADA',
#  'NEW HAMPSHIRE',
#  'NEW JERSEY',
#  'NEW MEXICO',
#  'NEW YORK',
#  'NORTH CAROLINA',
#  'NORTH DAKOTA',
#  'OHIO',
#  'OKLAHOMA',
#  'OREGON',
#  'PENNSYLVANIA',
#  'RHODE ISLAND',
#  'SOUTH CAROLINA',
#  'SOUTH DAKOTA',
#  'TENNESSEE',
#  'TEXAS',
#  'UTAH',
#  'VERMONT',
#  'VIRGINIA',
#  'WASHINGTON',
#  'WEST VIRGINIA',
#  'WISCONSIN',
#  'WYOMING',
#  'Footnotes:',
#  'Note: The symbol (B) means that the base is too small to show the derived measure.',
#  'Note: " - " Represents zero or rounds to zero.',
#  nan,
#  'Source: U.S. Census Bureau, Current Population Survey, November 2002.',
#  'Internet Release date:  July 28, 2004']

# %%
item
# Out:
# nan

# %%
count=0
countlast=0
for item in table[table.columns[0]]:
    if item[0]!='.':
        print item
        print count, count-countlast
        countlast=count
    count=count+1
# Out:
# All
# 0 0
# ALABAMA
# 10 10
# ALASKA
# 20 10
# ARIZONA
# 30 10
# ARKANSAS
# 40 10
# CALIFORNIA
# 50 10
# COLORADO
# 60 10
# CONNECTICUT
# 70 10
# DELAWARE
# 80 10
# DISTRICT OF COLUMBIA
# 90 10
# FLORIDA
# 100 10
# GEORGIA
# 110 10
# HAWAII
# 120 10
# IDAHO
# 130 10
# ILLINOIS
# 140 10
# INDIANA
# 150 10
# IOWA
# 160 10
# KANSAS
# 170 10
# KENTUCKY
# 180 10
# LOUISIANA
# 190 10
# MAINE
# 200 10
# MARYLAND
# 210 10
# MASSACHUSETTS
# 220 10
# MICHIGAN
# 230 10
# MINNESOTA
# 240 10
# MISSISSIPPI
# 250 10
# MISSOURI
# 260 10
# MONTANA
# 270 10
# NEBRASKA
# 280 10
# NEVADA
# 290 10
# NEW HAMPSHIRE
# 300 10
# NEW JERSEY
# 310 10
# NEW MEXICO
# 320 10
# NEW YORK
# 330 10
# NORTH CAROLINA
# 340 10
# NORTH DAKOTA
# 350 10
# OHIO
# 360 10
# OKLAHOMA
# 370 10
# OREGON
# 380 10
# PENNSYLVANIA
# 390 10
# RHODE ISLAND
# 400 10
# SOUTH CAROLINA
# 410 10
# SOUTH DAKOTA
# 420 10
# TENNESSEE
# 430 10
# TEXAS
# 440 10
# UTAH
# 450 10
# VERMONT
# 460 10
# VIRGINIA
# 470 10
# WASHINGTON
# 480 10
# WEST VIRGINIA
# 490 10
# WISCONSIN
# 500 10
# WYOMING
# 510 10
# Footnotes:
# 520 10
# Note: The symbol (B) means that the base is too small to show the derived measure.
# 521 1
# Note: " - " Represents zero or rounds to zero.
# 522 1
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-22-ca4420997e82> in <module>()
#       2 countlast=0
#       3 for item in table[table.columns[0]]:
# ----> 4     if item[0]!='.':
#       5         print item
#       6         print count, count-countlast
#
# TypeError: 'float' object has no attribute '__getitem__'

# %%
table2004[30:60]
# Out:
#            State, sex, race, and Hispanic origin Population 18 and over  \
# 30                                  .White alone                    359
# 31                    ..White non-Hispanic alone                    343
# 32                                  .Black alone                     13
# 33                                  .Asian alone                     24
# 34                       .Hispanic (of any race)                     22
# 35                .White alone or in combination                    376
# 36  ..White non-Hispanic alone or in combination                    359
# 37               .Black alone or in combination                      15
# 38                .Asian alone or in combination                     25
# 39                                       ARIZONA                    NaN
# 40                                        .Total                  4,122
# 41                                         .Male                  2,008
# 42                                       .Female                  2,114
# 43                           .Non-Hispanic White                  3,747
# 44                                  .White alone                  3,747
# 45                    ..White non-Hispanic alone                  2,622
# 46                                  .Black alone                    142
# 47                                  .Asian alone                     57
# 48                       .Hispanic (of any race)                  1,160
# 49                .White alone or in combination                  3,779
# 50  ..White non-Hispanic alone or in combination                  2,650
# 51               .Black alone or in combination                     152
# 52                .Asian alone or in combination                     63
# 53                                      ARKANSAS                    NaN
# 54                                        .Total                  2,010
# 55                                         .Male                    962
# 56                                       .Female                  1,048
# 57                                  .White alone                  1,649
# 58                    ..White non-Hispanic alone                  1,578
# 59                                  .Black alone                    295
#
#    Total citizen Percent citizen (18+) Margin of error1 Total    \
# 30           350                  97.3              0.8     278
# 31           336                  98.1              0.7     269
# 32            13                   (B)              (B)       9
# 33            17                   (B)              (B)       9
# 34            18                   (B)              (B)      13
# 35           367                  97.4              0.8     290
# 36           352                  98.1              0.7     280
# 37            14                   (B)              (B)      11
# 38            18                   (B)              (B)      10
# 39           NaN                   NaN              NaN     NaN
# 40         3,508                  85.1              1.7   2,485
# 41         1,687                  84.0              2.5   1,166
# 42         1,822                  86.2              2.3   1,319
# 43         3,168                  84.5              1.8   2,305
# 44         3,168                  84.5              1.8   2,305
# 45         2,564                  97.8              0.9   1,962
# 46           136                  95.7              6.2      81
# 47            38                   (B)              (B)      20
# 48           629                  54.2              7.0     354
# 49         3,196                  84.6              1.8   2,320
# 50         2,592                  97.8              0.9   1,977
# 51           146                  96.0              5.8      84
# 52            44                   (B)              (B)      23
# 53           NaN                   NaN              NaN     NaN
# 54         1,942                  96.6              0.9   1,328
# 55           926                  96.3              1.4     606
# 56         1,015                  96.9              1.2     723
# 57         1,593                  96.6              1.0   1,106
# 58         1,570                  99.5              0.4   1,096
# 59           295                 100.0                -     188
#
#    Percent registered (18+) Margin of error1 Total   Percent voted (18+)  \
# 30                     77.3              2.2     249                69.3
# 31                     78.4              2.2     241                70.4
# 32                      (B)              (B)       8                 (B)
# 33                      (B)              (B)       7                 (B)
# 34                      (B)              (B)      10                 (B)
# 35                     77.0              2.1     259                68.9
# 36                     78.0              2.1     251                69.9
# 37                      (B)              (B)       9                 (B)
# 38                      (B)              (B)       8                 (B)
# 39                      NaN              NaN     NaN                 NaN
# 40                     60.3              2.3   2,239                54.3
# 41                     58.0              3.3   1,034                51.5
# 42                     62.4              3.2   1,205                57.0
# 43                     61.5              2.4   2,094                55.9
# 44                     61.5              2.4   2,094                55.9
# 45                     74.8              2.6   1,803                68.8
# 46                     57.0             15.2      66                46.6
# 47                      (B)              (B)      17                 (B)
# 48                     30.5              6.4     296                25.5
# 49                     61.4              2.4   2,109                55.8
# 50                     74.6              2.6   1,818                68.6
# 51                     55.3             14.8      70                45.6
# 52                      (B)              (B)      20                 (B)
# 53                      NaN              NaN     NaN                 NaN
# 54                     66.1              2.4   1,140                56.7
# 55                     63.0              3.5     524                54.4
# 56                     69.0              3.2     617                58.9
# 57                     67.1              2.6     966                58.6
# 58                     69.4              2.6     959                60.8
# 59                     63.7              7.7     145                49.4
#
#    Margin of error1
# 30              2.4
# 31              2.4
# 32              (B)
# 33              (B)
# 34              (B)
# 35              2.3
# 36              2.4
# 37              (B)
# 38              (B)
# 39              NaN
# 40              2.3
# 41              3.4
# 42              3.3
# 43              2.5
# 44              2.5
# 45              2.7
# 46             15.3
# 47              (B)
# 48              6.1
# 49              2.4
# 50              2.7
# 51             14.8
# 52              (B)
# 53              NaN
# 54              2.5
# 55              3.6
# 56              3.4
# 57              2.7
# 58              2.8
# 59              8.0

# %%
table2008.ix[4,table2008.columns[0:3]]=table2008.ix[3,table2008.columns[0:3]]

# %%
table2006
# Out:
#     Table with row headers in column A and column headers in rows 5 through 6.  \
# 0    Table 4b. Reported Voting and Registration of ...
# 1                                       (In thousands)
# 2                      (leading dots indicate subpart)
# 3                State, sex, race, and Hispanic origin
# 4                                                  NaN
# 5                                                  NaN
# 6                                               .Total
# 7                                                .Male
# 8                                              .Female
# 9                                         .White alone
# 10                          ..White non-Hispanic alone
# 11                                        .Black alone
# 12                                        .Asian alone
# 13                             .Hispanic (of any race)
# 14                      .White alone or in combination
# 15                     .Black alone or in combination
# 16                      .Asian alone or in combination
# 17                                             ALABAMA
# 18                                              .Total
# 19                                               .Male
# 20                                             .Female
# 21                                        .White alone
# 22                          ..White non-Hispanic alone
# 23                                        .Black alone
# 24                                        .Asian alone
# 25                             .Hispanic (of any race)
# 26                      .White alone or in combination
# 27                     .Black alone or in combination
# 28                      .Asian alone or in combination
# 29                                              ALASKA
# ..                                                 ...
# 666                                                NaN
# 667                                                NaN
# 668                                                NaN
# 669                                                NaN
# 670                                                NaN
# 671                                                NaN
# 672                                                NaN
# 673                                                NaN
# 674                                                NaN
# 675                                                NaN
# 676                                                NaN
# 677                                                NaN
# 678                                                NaN
# 679                                                NaN
# 680                                                NaN
# 681                                                NaN
# 682                                                NaN
# 683                                                NaN
# 684                                                NaN
# 685                                                NaN
# 686                                                NaN
# 687                                                NaN
# 688                                                NaN
# 689                                                NaN
# 690                                                NaN
# 691                                                NaN
# 692                                                NaN
# 693                                                NaN
# 694                                                NaN
# 695                                                NaN
#
#            Unnamed: 1                Unnamed: 2        Unnamed: 3  \
# 0                 NaN                       NaN               NaN
# 1                 NaN                       NaN               NaN
# 2                 NaN                       NaN               NaN
# 3    Total Population  Total Citizen Population        Registered
# 4                 NaN                       NaN  Total Registered
# 5                 NaN                       NaN               NaN
# 6             220,603                   201,073           135,847
# 7             106,531                    96,144            63,425
# 8             114,073                   104,928            72,422
# 9             179,873                   165,637           115,135
# 10            152,998                   149,761           106,620
# 11             25,722                    24,229            14,765
# 12              9,855                     6,614             3,245
# 13             28,945                    17,315             9,304
# 14            182,564                   168,120           116,702
# 15             26,375                    24,814            15,142
# 16             10,474                     7,182             3,544
# 17                NaN                       NaN               NaN
# 18              3,447                     3,353             2,480
# 19              1,638                     1,566             1,187
# 20              1,809                     1,786             1,293
# 21              2,500                     2,430             1,824
# 22              2,431                     2,414             1,811
# 23                839                       839               602
# 24                 29                         6                 3
# 25                 69                        16                13
# 26              2,561                     2,491             1,861
# 27                854                       854               609
# 28                 36                        12                 7
# 29                NaN                       NaN               NaN
# ..                ...                       ...               ...
# 666               NaN                       NaN               NaN
# 667               NaN                       NaN               NaN
# 668               NaN                       NaN               NaN
# 669               NaN                       NaN               NaN
# 670               NaN                       NaN               NaN
# 671               NaN                       NaN               NaN
# 672               NaN                       NaN               NaN
# 673               NaN                       NaN               NaN
# 674               NaN                       NaN               NaN
# 675               NaN                       NaN               NaN
# 676               NaN                       NaN               NaN
# 677               NaN                       NaN               NaN
# 678               NaN                       NaN               NaN
# 679               NaN                       NaN               NaN
# 680               NaN                       NaN               NaN
# 681               NaN                       NaN               NaN
# 682               NaN                       NaN               NaN
# 683               NaN                       NaN               NaN
# 684               NaN                       NaN               NaN
# 685               NaN                       NaN               NaN
# 686               NaN                       NaN               NaN
# 687               NaN                       NaN               NaN
# 688               NaN                       NaN               NaN
# 689               NaN                       NaN               NaN
# 690               NaN                       NaN               NaN
# 691               NaN                       NaN               NaN
# 692               NaN                       NaN               NaN
# 693               NaN                       NaN               NaN
# 694               NaN                       NaN               NaN
# 695               NaN                       NaN               NaN
#
#                          Unnamed: 4        Unnamed: 5  \
# 0                               NaN               NaN
# 1                               NaN               NaN
# 2                               NaN               NaN
# 3                               NaN               NaN
# 4    Percent registered (Total 18+)  Margin of error1
# 5                               NaN               NaN
# 6                              61.6               0.3
# 7                              59.5               0.4
# 8                              63.5               0.4
# 9                              64.0               0.3
# 10                             69.7               0.3
# 11                             57.4               1.1
# 12                             32.9               1.7
# 13                             32.1               1.2
# 14                             63.9               0.3
# 15                             57.4               1.0
# 16                             33.8               1.6
# 17                              NaN               NaN
# 18                             72.0               2.1
# 19                             72.5               3.0
# 20                             71.5               2.9
# 21                             73.0               2.4
# 22                             74.5               2.4
# 23                             71.8               5.1
# 24                              (B)               (B)
# 25                              (B)               (B)
# 26                             72.7               2.4
# 27                             71.4               5.1
# 28                              (B)               (B)
# 29                              NaN               NaN
# ..                              ...               ...
# 666                             NaN               NaN
# 667                             NaN               NaN
# 668                             NaN               NaN
# 669                             NaN               NaN
# 670                             NaN               NaN
# 671                             NaN               NaN
# 672                             NaN               NaN
# 673                             NaN               NaN
# 674                             NaN               NaN
# 675                             NaN               NaN
# 676                             NaN               NaN
# 677                             NaN               NaN
# 678                             NaN               NaN
# 679                             NaN               NaN
# 680                             NaN               NaN
# 681                             NaN               NaN
# 682                             NaN               NaN
# 683                             NaN               NaN
# 684                             NaN               NaN
# 685                             NaN               NaN
# 686                             NaN               NaN
# 687                             NaN               NaN
# 688                             NaN               NaN
# 689                             NaN               NaN
# 690                             NaN               NaN
# 691                             NaN               NaN
# 692                             NaN               NaN
# 693                             NaN               NaN
# 694                             NaN               NaN
# 695                             NaN               NaN
#
#                            Unnamed: 6        Unnamed: 7   Unnamed: 8  \
# 0                                 NaN               NaN          NaN
# 1                                 NaN               NaN          NaN
# 2                                 NaN               NaN          NaN
# 3                                 NaN               NaN  Total Voted
# 4    Percent registered (Citizen 18+)  Margin of error1  Total Voted
# 5                                 NaN               NaN          NaN
# 6                                67.6               0.3       96,119
# 7                                66.0               0.4       45,118
# 8                                69.0               0.4       51,001
# 9                                69.5               0.3       82,387
# 10                               71.2               0.3       77,280
# 11                               60.9               1.0        9,937
# 12                               49.1               1.8        2,145
# 13                               53.7               1.3        5,595
# 14                               69.4               0.3       83,368
# 15                               61.0               1.0       10,169
# 16                               49.3               1.7        2,350
# 17                                NaN               NaN          NaN
# 18                               74.0               2.0        1,667
# 19                               75.8               2.9          792
# 20                               72.4               2.9          875
# 21                               75.1               2.4        1,241
# 22                               75.0               2.4        1,228
# 23                               71.8               5.1          401
# 24                                (B)               (B)            -
# 25                                (B)               (B)           13
# 26                               74.7               2.4        1,255
# 27                               71.4               5.1          405
# 28                                (B)               (B)            -
# 29                                NaN               NaN          NaN
# ..                                ...               ...          ...
# 666                               NaN               NaN          NaN
# 667                               NaN               NaN          NaN
# 668                               NaN               NaN          NaN
# 669                               NaN               NaN          NaN
# 670                               NaN               NaN          NaN
# 671                               NaN               NaN          NaN
# 672                               NaN               NaN          NaN
# 673                               NaN               NaN          NaN
# 674                               NaN               NaN          NaN
# 675                               NaN               NaN          NaN
# 676                               NaN               NaN          NaN
# 677                               NaN               NaN          NaN
# 678                               NaN               NaN          NaN
# 679                               NaN               NaN          NaN
# 680                               NaN               NaN          NaN
# 681                               NaN               NaN          NaN
# 682                               NaN               NaN          NaN
# 683                               NaN               NaN          NaN
# 684                               NaN               NaN          NaN
# 685                               NaN               NaN          NaN
# 686                               NaN               NaN          NaN
# 687                               NaN               NaN          NaN
# 688                               NaN               NaN          NaN
# 689                               NaN               NaN          NaN
# 690                               NaN               NaN          NaN
# 691                               NaN               NaN          NaN
# 692                               NaN               NaN          NaN
# 693                               NaN               NaN          NaN
# 694                               NaN               NaN          NaN
# 695                               NaN               NaN          NaN
#
#                     Unnamed: 9            ...             Unnamed: 204  \
# 0                          NaN            ...                      NaN
# 1                          NaN            ...                      NaN
# 2                          NaN            ...                      NaN
# 3                          NaN            ...                      NaN
# 4    Percent voted (Total 18+)            ...                      NaN
# 5                          NaN            ...                      NaN
# 6                         43.6            ...                      NaN
# 7                         42.4            ...                      NaN
# 8                         44.7            ...                      NaN
# 9                         45.8            ...                      NaN
# 10                        50.5            ...                      NaN
# 11                        38.6            ...                      NaN
# 12                        21.8            ...                      NaN
# 13                        19.3            ...                      NaN
# 14                        45.7            ...                      NaN
# 15                        38.6            ...                      NaN
# 16                        22.4            ...                      NaN
# 17                         NaN            ...                      NaN
# 18                        48.4            ...                      NaN
# 19                        48.4            ...                      NaN
# 20                        48.4            ...                      NaN
# 21                        49.6            ...                      NaN
# 22                        50.5            ...                      NaN
# 23                        47.8            ...                      NaN
# 24                         (B)            ...                      NaN
# 25                         (B)            ...                      NaN
# 26                        49.0            ...                      NaN
# 27                        47.5            ...                      NaN
# 28                         (B)            ...                      NaN
# 29                         NaN            ...                      NaN
# ..                         ...            ...                      ...
# 666                        NaN            ...                      NaN
# 667                        NaN            ...                      NaN
# 668                        NaN            ...                      NaN
# 669                        NaN            ...                      NaN
# 670                        NaN            ...                      NaN
# 671                        NaN            ...                      NaN
# 672                        NaN            ...                      NaN
# 673                        NaN            ...                      NaN
# 674                        NaN            ...                      NaN
# 675                        NaN            ...                      NaN
# 676                        NaN            ...                      NaN
# 677                        NaN            ...                      NaN
# 678                        NaN            ...                      NaN
# 679                        NaN            ...                      NaN
# 680                        NaN            ...                      NaN
# 681                        NaN            ...                      NaN
# 682                        NaN            ...                      NaN
# 683                        NaN            ...                      NaN
# 684                        NaN            ...                      NaN
# 685                        NaN            ...                      NaN
# 686                        NaN            ...                      NaN
# 687                        NaN            ...                      NaN
# 688                        NaN            ...                      NaN
# 689                        NaN            ...                      NaN
# 690                        NaN            ...                      NaN
# 691                        NaN            ...                      NaN
# 692                        NaN            ...                      NaN
# 693                        NaN            ...                      NaN
# 694                        NaN            ...                      NaN
# 695                        NaN            ...                      NaN
#
#     Unnamed: 205 Unnamed: 206  Unnamed: 207  Unnamed: 208  Unnamed: 209  \
# 0            NaN          NaN           NaN           NaN           NaN
# 1            NaN          NaN           NaN           NaN           NaN
# 2            NaN          NaN           NaN           NaN           NaN
# 3            NaN          NaN           NaN           NaN           NaN
# 4            NaN          NaN           NaN           NaN           NaN
# 5            NaN          NaN           NaN           NaN           NaN
# 6            NaN          NaN           NaN           NaN           NaN
# 7            NaN          NaN           NaN           NaN           NaN
# 8            NaN          NaN           NaN           NaN           NaN
# 9            NaN          NaN           NaN           NaN           NaN
# 10           NaN          NaN           NaN           NaN           NaN
# 11           NaN          NaN           NaN           NaN           NaN
# 12           NaN          NaN           NaN           NaN           NaN
# 13           NaN          NaN           NaN           NaN           NaN
# 14           NaN          NaN           NaN           NaN           NaN
# 15           NaN          NaN           NaN           NaN           NaN
# 16           NaN          NaN           NaN           NaN           NaN
# 17           NaN          NaN           NaN           NaN           NaN
# 18           NaN          NaN           NaN           NaN           NaN
# 19           NaN          NaN           NaN           NaN           NaN
# 20           NaN          NaN           NaN           NaN           NaN
# 21           NaN          NaN           NaN           NaN           NaN
# 22           NaN          NaN           NaN           NaN           NaN
# 23           NaN          NaN           NaN           NaN           NaN
# 24           NaN          NaN           NaN           NaN           NaN
# 25           NaN          NaN           NaN           NaN           NaN
# 26           NaN          NaN           NaN           NaN           NaN
# 27           NaN          NaN           NaN           NaN           NaN
# 28           NaN          NaN           NaN           NaN           NaN
# 29           NaN          NaN           NaN           NaN           NaN
# ..           ...          ...           ...           ...           ...
# 666          NaN          NaN           NaN           NaN           NaN
# 667          NaN          NaN           NaN           NaN           NaN
# 668          NaN          NaN           NaN           NaN           NaN
# 669          NaN          NaN           NaN           NaN           NaN
# 670          NaN          NaN           NaN           NaN           NaN
# 671          NaN          NaN           NaN           NaN           NaN
# 672          NaN          NaN           NaN           NaN           NaN
# 673          NaN          NaN           NaN           NaN           NaN
# 674          NaN          NaN           NaN           NaN           NaN
# 675          NaN          NaN           NaN           NaN           NaN
# 676          NaN          NaN           NaN           NaN           NaN
# 677          NaN          NaN           NaN           NaN           NaN
# 678          NaN          NaN           NaN           NaN           NaN
# 679          NaN          NaN           NaN           NaN           NaN
# 680          NaN          NaN           NaN           NaN           NaN
# 681          NaN          NaN           NaN           NaN           NaN
# 682          NaN          NaN           NaN           NaN           NaN
# 683          NaN          NaN           NaN           NaN           NaN
# 684          NaN          NaN           NaN           NaN           NaN
# 685          NaN          NaN           NaN           NaN           NaN
# 686          NaN          NaN           NaN           NaN           NaN
# 687          NaN          NaN           NaN           NaN           NaN
# 688          NaN          NaN           NaN           NaN           NaN
# 689          NaN          NaN           NaN           NaN           NaN
# 690          NaN          NaN           NaN           NaN           NaN
# 691          NaN          NaN           NaN           NaN           NaN
# 692          NaN          NaN           NaN           NaN           NaN
# 693          NaN          NaN           NaN           NaN           NaN
# 694          NaN          NaN           NaN           NaN           NaN
# 695          NaN          NaN           NaN           NaN           NaN
#
#      Unnamed: 210  Unnamed: 211  Unnamed: 212  Unnamed: 213
# 0             NaN           NaN           NaN           NaN
# 1             NaN           NaN           NaN           NaN
# 2             NaN           NaN           NaN           NaN
# 3             NaN           NaN           NaN           NaN
# 4             NaN           NaN           NaN           NaN
# 5             NaN           NaN           NaN           NaN
# 6             NaN           NaN           NaN           NaN
# 7             NaN           NaN           NaN           NaN
# 8             NaN           NaN           NaN           NaN
# 9             NaN           NaN           NaN           NaN
# 10            NaN           NaN           NaN           NaN
# 11            NaN           NaN           NaN           NaN
# 12            NaN           NaN           NaN           NaN
# 13            NaN           NaN           NaN           NaN
# 14            NaN           NaN           NaN           NaN
# 15            NaN           NaN           NaN           NaN
# 16            NaN           NaN           NaN           NaN
# 17            NaN           NaN           NaN           NaN
# 18            NaN           NaN           NaN           NaN
# 19            NaN           NaN           NaN           NaN
# 20            NaN           NaN           NaN           NaN
# 21            NaN           NaN           NaN           NaN
# 22            NaN           NaN           NaN           NaN
# 23            NaN           NaN           NaN           NaN
# 24            NaN           NaN           NaN           NaN
# 25            NaN           NaN           NaN           NaN
# 26            NaN           NaN           NaN           NaN
# 27            NaN           NaN           NaN           NaN
# 28            NaN           NaN           NaN           NaN
# 29            NaN           NaN           NaN           NaN
# ..            ...           ...           ...           ...
# 666           NaN           NaN           NaN           NaN
# 667           NaN           NaN           NaN           NaN
# 668           NaN           NaN           NaN           NaN
# 669           NaN           NaN           NaN           NaN
# 670           NaN           NaN           NaN           NaN
# 671           NaN           NaN           NaN           NaN
# 672           NaN           NaN           NaN           NaN
# 673           NaN           NaN           NaN           NaN
# 674           NaN           NaN           NaN           NaN
# 675           NaN           NaN           NaN           NaN
# 676           NaN           NaN           NaN           NaN
# 677           NaN           NaN           NaN           NaN
# 678           NaN           NaN           NaN           NaN
# 679           NaN           NaN           NaN           NaN
# 680           NaN           NaN           NaN           NaN
# 681           NaN           NaN           NaN           NaN
# 682           NaN           NaN           NaN           NaN
# 683           NaN           NaN           NaN           NaN
# 684           NaN           NaN           NaN           NaN
# 685           NaN           NaN           NaN           NaN
# 686           NaN           NaN           NaN           NaN
# 687           NaN           NaN           NaN           NaN
# 688           NaN           NaN           NaN           NaN
# 689           NaN           NaN           NaN           NaN
# 690           NaN           NaN           NaN           NaN
# 691           NaN           NaN           NaN           NaN
# 692           NaN           NaN           NaN           NaN
# 693           NaN           NaN           NaN           NaN
# 694           NaN           NaN           NaN           NaN
# 695           NaN           NaN           NaN           NaN
#
# [696 rows x 214 columns]

# %%
table2012
table2010
table2008
table2006
table2004
