# %%
import requests, zipfile, StringIO
import pandas as pd
from pandas import DataFrame, read_csv
import math
import numpy as np

# %%
urllist=['http://www.census.gov/hhes/www/socdemo/voting/publications/p20/2012/Table04b.csv','http://www.census.gov/hhes/www/socdemo/voting/publications/p20/2010/Table4b_2010.csv', 'http://www.census.gov/hhes/www/socdemo/voting/publications/p20/2008/Table%2004b.csv', 'http://www.census.gov/hhes/www/socdemo/voting/publications/p20/2006/tab04b.csv']

# %%
count=0
for year in [2012, 2010, 2008, 2006]:
    url=urllist[(2012-year)/2]
    table=pd.read_csv(StringIO.StringIO(requests.get(url).content))
    if (year==2012):
        changeCol=dict(zip(table.columns, table.ix[2,:]))#change the columns to match what we want them to be #this portion also not analgous for years
        table.rename(columns=changeCol, inplace=True)
        table=table.drop([0,1,2]).reset_index(drop=True)#ditto this part
        table=table.ix[:,(~pd.isnull(table.columns))] #removing extra nan columns
        stateDict=dict(zip([table.ix[11*i,0] for i in range(52)], [table[11*i:11*(i+1)] for i in range(52)]))#dictionary for info on each state 
    elif year==2010:
        changeCol=dict(zip(table.columns, table.ix[1,:]))#change the columns to match what we want them to be #this portion also not analgous for years
        table.rename(columns=changeCol, inplace=True)
        table=table.drop([0,1]).reset_index(drop=True)#ditto this part
        table=table.ix[:, 0:14]
        table.ix[0, 'STATE']='All'
        for i in range(52):
               stateDict[table.ix[11*i,0]]=[stateDict[table.ix[11*i,0]], table[11*i:11*(i+1)]]
    elif year==2008:
        table.ix[4,table.columns[0:3]]=table.ix[3,table.columns[0:3]]
        changeCol=dict(zip(table.columns, table.ix[4,:]))#change the columns to match what we want them to be #this portion also not analgous for years
        table.rename(columns=changeCol, inplace=True)
        table=table.drop([0,1,2,3,4]).reset_index(drop=True)#ditto this part
        table=table.ix[:,(~pd.isnull(table.columns))] #removing extra nan columns
        table.ix[0, 'State, sex, race, and Hispanic origin']='All'
        for i in range(52):
            existinglist=stateDict[table.ix[12*i,0]]
            existinglist.append(table[12*i:12*(i+1)])
            stateDict[table.ix[12*i,0]]=existinglist
    elif year==2006
        #elif year==2010:
        #    for i in range(52):
        #       stateDict[table.ix[11*i,0]]=[stateDict[table.ix[11*i,0]], table[11*i:11*(i+1)]]
        #elif (year==2008)|(year==2006):
        #     for i in range(52):
        #         existinglist=stateDict[table.ix[11*i,0]]
        #         existinglist.append(table[11*i:11*(i+1)])
        #         stateDict[table.ix[11*i,0]]=existinglist 
    else:
        table2006=table
# Out:
# ['VERMONT', 'GEORGIA', 'IOWA', 'KANSAS', 'FLORIDA', 'VIRGINIA', 'NORTH CAROLINA', 'HAWAII', 'NEW YORK', 'CALIFORNIA', 'ALABAMA', 'IDAHO', 'DELAWARE', 'ALASKA', 'ILLINOIS', 'SOUTH DAKOTA', 'CONNECTICUT', 'MONTANA', 'MASSACHUSETTS', 'NEW HAMPSHIRE', 'MARYLAND', 'NEW MEXICO', 'MISSISSIPPI', 'TENNESSEE', 'COLORADO', 'NEW JERSEY', 'UTAH', 'MICHIGAN', 'WEST VIRGINIA', 'WASHINGTON', 'MINNESOTA', 'OREGON', 'WYOMING', 'OHIO', 'SOUTH CAROLINA', 'INDIANA', 'NEVADA', 'LOUISIANA', 'NEBRASKA', 'All', 'ARIZONA', 'WISCONSIN', 'NORTH DAKOTA', 'PENNSYLVANIA', 'OKLAHOMA', 'KENTUCKY', 'RHODE ISLAND', 'DISTRICT OF COLUMBIA', 'ARKANSAS', 'MISSOURI', 'TEXAS', 'MAINE']

# %%
url2012='http://www.census.gov/hhes/www/socdemo/voting/publications/p20/2012/Table04b.csv' #url for sex and race
url2010='http://www.census.gov/hhes/www/socdemo/voting/publications/p20/2010/Table4b_2010.csv'#urls are not analgous for other years
url2008 = 'http://www.census.gov/hhes/www/socdemo/voting/publications/p20/2008/Table%2004b.csv'
url2006 = 'http://www.census.gov/hhes/www/socdemo/voting/publications/p20/2006/tab04b.csv'
url2004= 'http://www.census.gov/hhes/www/socdemo/voting/publications/p20/2004/tab04a.csv' #error message for year 2004
table=pd.read_csv(StringIO.StringIO(requests.get(url2006).content)) #read in CSV

# %%
changeCol=dict(zip(table.columns, table.ix[2,:]))#change the columns to match what we want them to be #this portion also not analgous for years
table.rename(columns=changeCol, inplace=True)
table=table.drop([0,1,2]).reset_index(drop=True)#ditto this part
table=table.ix[:,(~pd.isnull(table.columns))] #removing extra nan columns

# %%
#Note: I found how many non-nan entries there were with (~pd.isnull(table['State'])).sum() 
stateDict['ARKANSAS'][2]
# Out:
#    State, sex, race, and Hispanic origin Total Population  \
# 48                              ARKANSAS              NaN
# 49                                .Total            2,108
# 50                                 .Male            1,002
# 51                               .Female            1,106
# 52                          .White alone            1,733
# 53            ..White non-Hispanic alone            1,658
# 54                          .Black alone              308
# 55                          .Asian alone               23
# 56               .Hispanic (of any race)               74
# 57        .White alone or in combination            1,768
# 58       .Black alone or in combination               313
# 59        .Asian alone or in combination               23
#
#    Total Citizen Population Total Registered Percent registered (Total 18+)  \
# 48                      NaN              NaN                            NaN
# 49                    2,030            1,317                           62.5
# 50                      952              584                           58.2
# 51                    1,078              734                           66.3
# 52                    1,679            1,125                           64.9
# 53                    1,658            1,117                           67.4
# 54                      301              160                           52.0
# 55                        6                -                            (B)
# 56                       20                8                            (B)
# 57                    1,714            1,152                           65.1
# 58                      306              164                           52.2
# 59                        6                -                            (B)
#
#    Margin of error1 Percent registered (Citizen 18+) Margin of error1  \
# 48              NaN                              NaN              NaN
# 49              2.5                             64.9              2.5
# 50              3.7                             61.3              3.6
# 51              3.4                             68.1              3.3
# 52              2.7                             67.0              2.7
# 53              2.7                             67.4              2.7
# 54              8.1                             53.2              8.1
# 55              (B)                              (B)              (B)
# 56              (B)                              (B)              (B)
# 57              2.7                             67.2              2.6
# 58              8.1                             53.4              8.0
# 59              (B)                              (B)              (B)
#
#    Total Voted Percent voted (Total 18+) Margin of error1  \
# 48         NaN                       NaN              NaN
# 49       1,092                      51.8              2.6
# 50         477                      47.6              3.7
# 51         615                      55.6              3.5
# 52         931                      53.7              2.8
# 53         928                      55.9              2.9
# 54         133                      43.1              8.0
# 55           -                       (B)              (B)
# 56           3                       (B)              (B)
# 57         954                      53.9              2.8
# 58         136                      43.5              8.0
# 59           -                       (B)              (B)
#
#    Percent voted (Citizen 18+) Margin of error1
# 48                         NaN              NaN
# 49                        53.8              2.6
# 50                        50.1              3.7
# 51                        57.1              3.5
# 52                        55.5              2.8
# 53                        55.9              2.9
# 54                        44.1              8.1
# 55                         (B)              (B)
# 56                         (B)              (B)
# 57                        55.6              2.8
# 58                        44.5              8.0
# 59                         (B)              (B)

# %%
table2010
changeCol=dict(zip(table2010.columns, table2010.ix[2,:]))
table2010.rename(columns=changeCol, inplace=True)

# %%
table2008
changeCol=dict(zip(table2008.columns[0:2], table2008.ix[3,0:2]))#change the columns to match what we want them to be #this portion also not analgous for years
table2008.rename(columns=changeCol, inplace=True)
changeCol=dict(zip(table2008.columns[3:], table2008.ix[4,3:]))#change the columns to match what we want them to be #this portion also not analgous for years
table2008.rename(columns=changeCol, inplace=True)

# %%
blah=table2010.columns[1]
print type(blah)
print float('nan')
what=dict({float('nan'): 'Total'})
what[float('nan')]
# Out:
# <type 'float'>
# nan
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-32-e43f81542b59> in <module>()
#       3 print float('nan')
#       4 what=dict({float('nan'): 'Total'})
# ----> 5 what[float('nan')]
#
# KeyError: nan

# %%
table2008.ix[4,table2008.columns[0:3]]=table2008.ix[3,table2008.columns[0:3]]

# %%
table2008
# Out:
#     State, sex, race, and Hispanic origin Total Population  \
# 0                                     All          225,499
# 1                                   .Male          108,974
# 2                                 .Female          116,525
# 3                            .White alone          183,169
# 4              ..White non-Hispanic alone          154,472
# 5                            .Black alone           26,528
# 6                            .Asian alone           10,455
# 7                 .Hispanic (of any race)           30,852
# 8          .White alone or in combination          185,773
# 9         .Black alone or in combination            27,483
# 10         .Asian alone or in combination           11,009
# 11                                ALABAMA              NaN
# 12                                 .Total            3,497
# 13                                  .Male            1,654
# 14                                .Female            1,843
# 15                           .White alone            2,541
# 16             ..White non-Hispanic alone            2,474
# 17                           .Black alone              875
# 18                           .Asian alone               32
# 19                .Hispanic (of any race)               71
# 20         .White alone or in combination            2,579
# 21        .Black alone or in combination               892
# 22         .Asian alone or in combination               32
# 23                                 ALASKA              NaN
# 24                                 .Total              488
# 25                                  .Male              246
# 26                                .Female              242
# 27                           .White alone              364
# 28             ..White non-Hispanic alone              351
# 29                           .Black alone               17
# ..                                    ...              ...
# 693                                   NaN              NaN
# 694                                   NaN              NaN
# 695                                   NaN              NaN
# 696                                   NaN              NaN
# 697                                   NaN              NaN
# 698                                   NaN              NaN
# 699                                   NaN              NaN
# 700                                   NaN              NaN
# 701                                   NaN              NaN
# 702                                   NaN              NaN
# 703                                   NaN              NaN
# 704                                   NaN              NaN
# 705                                   NaN              NaN
# 706                                   NaN              NaN
# 707                                   NaN              NaN
# 708                                   NaN              NaN
# 709                                   NaN              NaN
# 710                                   NaN              NaN
# 711                                   NaN              NaN
# 712                                   NaN              NaN
# 713                                   NaN              NaN
# 714                                   NaN              NaN
# 715                                   NaN              NaN
# 716                                   NaN              NaN
# 717                                   NaN              NaN
# 718                                   NaN              NaN
# 719                                   NaN              NaN
# 720                                   NaN              NaN
# 721                                   NaN              NaN
# 722                                   NaN              NaN
#
#     Total Citizen Population Total Registered Percent registered (Total 18+)  \
# 0                    206,072          146,311                           64.9
# 1                     98,818           68,242                           62.6
# 2                    107,255           78,069                           67.0
# 3                    169,438          122,020                           66.6
# 4                    151,321          111,215                           72.0
# 5                     24,930           17,375                           65.5
# 6                      7,059            3,901                           37.3
# 7                     19,537           11,608                           37.6
# 8                    171,798          123,628                           66.5
# 9                     25,768           17,960                           65.3
# 10                     7,562            4,225                           38.4
# 11                       NaN              NaN                            NaN
# 12                     3,404            2,438                           69.7
# 13                     1,593            1,092                           66.0
# 14                     1,811            1,346                           73.0
# 15                     2,473            1,791                           70.5
# 16                     2,470            1,791                           72.4
# 17                       875              611                           69.9
# 18                         8                -                            (B)
# 19                         7                4                            (B)
# 20                     2,511            1,824                           70.7
# 21                       892              626                           70.1
# 22                         8                -                            (B)
# 23                       NaN              NaN                            NaN
# 24                       468              345                           70.8
# 25                       241              171                           69.6
# 26                       228              174                           72.0
# 27                       355              278                           76.4
# 28                       344              271                           77.1
# 29                        15               10                            (B)
# ..                       ...              ...                            ...
# 693                      NaN              NaN                            NaN
# 694                      NaN              NaN                            NaN
# 695                      NaN              NaN                            NaN
# 696                      NaN              NaN                            NaN
# 697                      NaN              NaN                            NaN
# 698                      NaN              NaN                            NaN
# 699                      NaN              NaN                            NaN
# 700                      NaN              NaN                            NaN
# 701                      NaN              NaN                            NaN
# 702                      NaN              NaN                            NaN
# 703                      NaN              NaN                            NaN
# 704                      NaN              NaN                            NaN
# 705                      NaN              NaN                            NaN
# 706                      NaN              NaN                            NaN
# 707                      NaN              NaN                            NaN
# 708                      NaN              NaN                            NaN
# 709                      NaN              NaN                            NaN
# 710                      NaN              NaN                            NaN
# 711                      NaN              NaN                            NaN
# 712                      NaN              NaN                            NaN
# 713                      NaN              NaN                            NaN
# 714                      NaN              NaN                            NaN
# 715                      NaN              NaN                            NaN
# 716                      NaN              NaN                            NaN
# 717                      NaN              NaN                            NaN
# 718                      NaN              NaN                            NaN
# 719                      NaN              NaN                            NaN
# 720                      NaN              NaN                            NaN
# 721                      NaN              NaN                            NaN
# 722                      NaN              NaN                            NaN
#
#     Margin of error1 Percent registered (Citizen 18+) Margin of error1  \
# 0                0.3                             71.0              0.3
# 1                0.4                             69.1              0.4
# 2                0.4                             72.8              0.4
# 3                0.3                             72.0              0.3
# 4                0.3                             73.5              0.3
# 5                1.0                             69.7              1.0
# 6                1.7                             55.3              1.7
# 7                1.2                             59.4              1.2
# 8                0.3                             72.0              0.3
# 9                1.0                             69.7              0.9
# 10               1.7                             55.9              1.7
# 11               NaN                              NaN              NaN
# 12               2.3                             71.6              2.2
# 13               3.4                             68.5              3.4
# 14               3.0                             74.3              3.0
# 15               2.7                             72.4              2.6
# 16               2.7                             72.5              2.6
# 17               5.5                             69.9              5.5
# 18               (B)                              (B)              (B)
# 19               (B)                              (B)              (B)
# 20               2.6                             72.6              2.6
# 21               5.5                             70.1              5.5
# 22               (B)                              (B)              (B)
# 23               NaN                              NaN              NaN
# 24               2.4                             73.7              2.4
# 25               3.5                             71.1              3.4
# 26               3.4                             76.5              3.2
# 27               2.6                             78.4              2.6
# 28               2.7                             78.7              2.6
# 29               (B)                              (B)              (B)
# ..               ...                              ...              ...
# 693              NaN                              NaN              NaN
# 694              NaN                              NaN              NaN
# 695              NaN                              NaN              NaN
# 696              NaN                              NaN              NaN
# 697              NaN                              NaN              NaN
# 698              NaN                              NaN              NaN
# 699              NaN                              NaN              NaN
# 700              NaN                              NaN              NaN
# 701              NaN                              NaN              NaN
# 702              NaN                              NaN              NaN
# 703              NaN                              NaN              NaN
# 704              NaN                              NaN              NaN
# 705              NaN                              NaN              NaN
# 706              NaN                              NaN              NaN
# 707              NaN                              NaN              NaN
# 708              NaN                              NaN              NaN
# 709              NaN                              NaN              NaN
# 710              NaN                              NaN              NaN
# 711              NaN                              NaN              NaN
# 712              NaN                              NaN              NaN
# 713              NaN                              NaN              NaN
# 714              NaN                              NaN              NaN
# 715              NaN                              NaN              NaN
# 716              NaN                              NaN              NaN
# 717              NaN                              NaN              NaN
# 718              NaN                              NaN              NaN
# 719              NaN                              NaN              NaN
# 720              NaN                              NaN              NaN
# 721              NaN                              NaN              NaN
# 722              NaN                              NaN              NaN
#
#     Total Voted Percent voted (Total 18+) Margin of error1  \
# 0       131,144                      58.2              0.3
# 1        60,729                      55.7              0.4
# 2        70,415                      60.4              0.4
# 3       109,100                      59.6              0.3
# 4       100,042                      64.8              0.3
# 5        16,133                      60.8              1.0
# 6         3,357                      32.1              1.6
# 7         9,745                      31.6              1.2
# 8       110,500                      59.5              0.3
# 9        16,674                      60.7              1.0
# 10        3,627                      32.9              1.6
# 11          NaN                       NaN              NaN
# 12        2,126                      60.8              2.4
# 13          927                      56.1              3.6
# 14        1,199                      65.0              3.3
# 15        1,543                      60.7              2.9
# 16        1,543                      62.4              2.9
# 17          547                      62.5              5.8
# 18            -                       (B)              (B)
# 19            4                       (B)              (B)
# 20        1,576                      61.1              2.8
# 21          561                      62.9              5.8
# 22            -                       (B)              (B)
# 23          NaN                       NaN              NaN
# 24          304                      62.4              2.6
# 25          152                      61.8              3.7
# 26          152                      62.9              3.7
# 27          251                      69.0              2.9
# 28          245                      69.8              2.9
# 29            7                       (B)              (B)
# ..          ...                       ...              ...
# 693         NaN                       NaN              NaN
# 694         NaN                       NaN              NaN
# 695         NaN                       NaN              NaN
# 696         NaN                       NaN              NaN
# 697         NaN                       NaN              NaN
# 698         NaN                       NaN              NaN
# 699         NaN                       NaN              NaN
# 700         NaN                       NaN              NaN
# 701         NaN                       NaN              NaN
# 702         NaN                       NaN              NaN
# 703         NaN                       NaN              NaN
# 704         NaN                       NaN              NaN
# 705         NaN                       NaN              NaN
# 706         NaN                       NaN              NaN
# 707         NaN                       NaN              NaN
# 708         NaN                       NaN              NaN
# 709         NaN                       NaN              NaN
# 710         NaN                       NaN              NaN
# 711         NaN                       NaN              NaN
# 712         NaN                       NaN              NaN
# 713         NaN                       NaN              NaN
# 714         NaN                       NaN              NaN
# 715         NaN                       NaN              NaN
# 716         NaN                       NaN              NaN
# 717         NaN                       NaN              NaN
# 718         NaN                       NaN              NaN
# 719         NaN                       NaN              NaN
# 720         NaN                       NaN              NaN
# 721         NaN                       NaN              NaN
# 722         NaN                       NaN              NaN
#
#     Percent voted (Citizen 18+) Margin of error1
# 0                          63.6              0.3
# 1                          61.5              0.4
# 2                          65.7              0.4
# 3                          64.4              0.3
# 4                          66.1              0.3
# 5                          64.7              1.0
# 6                          47.6              1.7
# 7                          49.9              1.3
# 8                          64.3              0.3
# 9                          64.7              1.0
# 10                         48.0              1.7
# 11                          NaN              NaN
# 12                         62.4              2.4
# 13                         58.2              3.6
# 14                         66.2              3.2
# 15                         62.4              2.8
# 16                         62.5              2.9
# 17                         62.5              5.8
# 18                          (B)              (B)
# 19                          (B)              (B)
# 20                         62.8              2.8
# 21                         62.9              5.8
# 22                          (B)              (B)
# 23                          NaN              NaN
# 24                         65.0              2.6
# 25                         63.2              3.6
# 26                         66.8              3.6
# 27                         70.8              2.8
# 28                         71.2              2.9
# 29                          (B)              (B)
# ..                          ...              ...
# 693                         NaN              NaN
# 694                         NaN              NaN
# 695                         NaN              NaN
# 696                         NaN              NaN
# 697                         NaN              NaN
# 698                         NaN              NaN
# 699                         NaN              NaN
# 700                         NaN              NaN
# 701                         NaN              NaN
# 702                         NaN              NaN
# 703                         NaN              NaN
# 704                         NaN              NaN
# 705                         NaN              NaN
# 706                         NaN              NaN
# 707                         NaN              NaN
# 708                         NaN              NaN
# 709                         NaN              NaN
# 710                         NaN              NaN
# 711                         NaN              NaN
# 712                         NaN              NaN
# 713                         NaN              NaN
# 714                         NaN              NaN
# 715                         NaN              NaN
# 716                         NaN              NaN
# 717                         NaN              NaN
# 718                         NaN              NaN
# 719                         NaN              NaN
# 720                         NaN              NaN
# 721                         NaN              NaN
# 722                         NaN              NaN
#
# [723 rows x 13 columns]

# %%
table2012
table2010
table2008
table2006
table2004
