# %%
import requests, zipfile, StringIO
import pandas as pd
from pandas import DataFrame, read_csv
import math
import numpy as np

# %%
#Voting registration by Sex, Race and Hispanic Origin, for States 

url_2012 = 'http://www.census.gov/hhes/www/socdemo/voting/publications/p20/2012/Table04b.csv'
url_2010 = 'http://www.census.gov/hhes/www/socdemo/voting/publications/p20/2010/Table4b_2010.csv'
url_2008 = 'http://www.census.gov/hhes/www/socdemo/voting/publications/p20/2008/Table%2004b.csv'
url_2006 = 'http://www.census.gov/hhes/www/socdemo/voting/publications/p20/2006/tab04b.csv'
url_2004 = 'http://www.census.gov/hhes/www/socdemo/voting/publications/p20/2004/tab04a.csv'
url_2002 = 'http://www.census.gov/hhes/www/socdemo/voting/publications/p20/2002/tab04a.csv'
urllist=[url_2012, url_2010, url_2008, url_2006, url_2004, url_2002]

# %%
#general comment (Kate): there are functions below(ie SplitStatebyDot) which could have made this portion easier
#but I didn't make them until I was done with this portion. 
for year in [2012, 2010, 2008, 2006, 2004, 2002]:
    url=urllist[(2012-year)/2]
    table=pd.read_csv(StringIO.StringIO(requests.get(url).content),error_bad_lines=False)
    
    if (year==2012):
        changeCol=dict(zip(table.columns, table.ix[2,:]))#change the columns to match what we want them to be 
        table.rename(columns=changeCol, inplace=True)
        table=table.drop([0,1,2]).reset_index(drop=True)# we don't want these first few columns
        table=table.ix[:,(~pd.isnull(table.columns))] #removing extra nan columns
        stateDictRace=dict(zip([table.ix[11*i,0] for i in range(52)], [table[11*i:11*(i+1)] for i in range(52)]))
             #dictionary for info on each state
            
    elif year==2010:
        changeCol=dict(zip(table.columns, table.ix[1,:]))#change the columns to match what we want them to be #this portion also not analgous for years
        table.rename(columns=changeCol, inplace=True)
        table=table.drop([0,1]).reset_index(drop=True)#ditto this part
        table=table.ix[:, 0:14]
        table.ix[0, 'STATE']='All'
        for i in range(52):
               stateDictRace[table.ix[11*i,0]]=[stateDictRace[table.ix[11*i,0]], table[11*i:11*(i+1)]]#modify the dictionary
#each year needs its own case because the tables come in formatted differently. I tried to combine them to reuse code wherever possible. 
                
    elif (year==2008)|(year==2006)|(year==2004)|(year==2002):
        table.ix[4,table.columns[0:3]]=table.ix[3,table.columns[0:3]]
        changeCol=dict(zip(table.columns, table.ix[4,:]))#change the columns to match what we want them to be #this portion also not analgous for years
        table.rename(columns=changeCol, inplace=True)
        table=table.drop([0,1,2,3,4]).reset_index(drop=True)#ditto this part
        table=table.ix[:,(~pd.isnull(table.columns))] #removing extra nan columns
        if year==2002:
            for i in range(52):
                table.ix[0, 'STATE']='All'
                existinglist=stateDictRace[table.ix[10*i,0]]#modify the dictionary again
                existinglist.append(table[10*i:10*(i+1)])
                stateDictRace[table.ix[10*i,0]]=existinglist
        else:
            table.ix[0, 'State, sex, race, and Hispanic origin']='All'
        if year==2004:
            table=table.drop([43]).reset_index(drop=True)#one state has a duplicate row
            for i in range(49): #something weird - don't have data for all states in 2004 (missing West Virginia, Wymoning, Wisconsin?)
                existinglist=stateDictRace[table.ix[13*i,0]]
                existinglist.append(table[13*i:13*(i+1)])
                stateDictRace[table.ix[13*i,0]]=existinglist
        elif (year==2006)|(year==2008):
            for i in range(52):
                existinglist=stateDictRace[table.ix[12*i,0]]
                existinglist.append(table[12*i:12*(i+1)])
                stateDictRace[table.ix[12*i,0]]=existinglist
# Out:
# Skipping line 657: expected 13 fields, saw 24
# Skipping line 658: expected 13 fields, saw 24
# Skipping line 659: expected 13 fields, saw 24
# Skipping line 660: expected 13 fields, saw 24
# Skipping line 661: expected 13 fields, saw 24
# Skipping line 662: expected 13 fields, saw 24
# Skipping line 663: expected 13 fields, saw 24
# Skipping line 664: expected 13 fields, saw 24
# Skipping line 665: expected 13 fields, saw 24
# Skipping line 666: expected 13 fields, saw 24
# Skipping line 667: expected 13 fields, saw 24
# Skipping line 668: expected 13 fields, saw 24
# Skipping line 669: expected 13 fields, saw 24
# Skipping line 670: expected 13 fields, saw 24
# Skipping line 671: expected 13 fields, saw 24
# Skipping line 672: expected 13 fields, saw 24
# Skipping line 673: expected 13 fields, saw 37
# Skipping line 674: expected 13 fields, saw 37
# Skipping line 675: expected 13 fields, saw 37
# Skipping line 676: expected 13 fields, saw 37
# Skipping line 677: expected 13 fields, saw 37
# Skipping line 678: expected 13 fields, saw 37
# Skipping line 679: expected 13 fields, saw 37
# Skipping line 680: expected 13 fields, saw 37
# Skipping line 681: expected 13 fields, saw 37
# Skipping line 682: expected 13 fields, saw 37
# Skipping line 683: expected 13 fields, saw 37
# Skipping line 684: expected 13 fields, saw 37
# Skipping line 685: expected 13 fields, saw 37
# Skipping line 686: expected 13 fields, saw 37
# Skipping line 687: expected 13 fields, saw 37
# Skipping line 688: expected 13 fields, saw 37

# %%
#this function takes in a table where states are distinguished from demographic information by a dot (.) in front of the latter, returning a list of states and a list of tables for each state
def splitbyStateDot(table):
    indices=pd.DataFrame([item[0]=='.' for item in table[table.columns[0]][0:(len(table)-5)]])#trying to find states automatically
    indices=indices.append([False, False, False, False, False]).reset_index(drop=True)
    firstcol=table[table.columns[0]].reset_index(drop=True)
    statesLoc=firstcol[indices[0]==False].index
    return [item for item in firstcol[indices[0]==False]], [table.ix[statesLoc[i]:(statesLoc[i+1]-1), :] for i in range(len(statesLoc)-1)]

# %%
#this function takes in a table where states are distinguished from demographic information by nan in front of the latter, returning a list of states and a list of tables for each state

def splitbyStateNull(table):
    indices=table[table.columns[0]].isnull()
    indices[len(indices)-5:len(indices)]=False
    firstcol=table[table.columns[0]]
    statesLoc=firstcol[indices==False].index
    return [item for item in firstcol[indices==False]], [table.ix[statesLoc[i]:(statesLoc[i+1]-1), :] for i in range(len(statesLoc)-1)]

# %%
#Voting registration by AGE, for States, for years 2002, 2004, 2008, 2010, 2012
#NOTE: Missing the year 2006 due to a gap in the data

urllist2=['http://www.census.gov/hhes/www/socdemo/voting/publications/p20/2012/Table04c.csv', 'http://www.census.gov/hhes/www/socdemo/voting/publications/p20/2010/Table4c_2010.csv' ,'http://www.census.gov/hhes/www/socdemo/voting/publications/p20/2008/Table%2004c.csv', 'http://www.census.gov/hhes/www/socdemo/voting/publications/p20/2004/tab04b.csv','http://www.census.gov/hhes/www/socdemo/voting/publications/p20/2002/tab04b.csv']

# %%
#Defines stateDictAge and stateDictRace
#Meena comment:  Should stateDictAge and stateDictRace be defined out here as blank dictionaries, so that their scope is global?
#Kate comment: their scope is global (if I'm understanding you correctly). You can use it in a different cell and it will still work. 

for year in [2012, 2010, 2008, 2006, 2004]:
    url=urllist2[(2012-year)/2]
    table=pd.read_csv(StringIO.StringIO(requests.get(url).content),error_bad_lines=False)
    if (year==2012):
        changeCol=dict(zip(table.columns, table.ix[2,:]))#change the columns to match what we want them to be 
        table.rename(columns=changeCol, inplace=True)
        table=table.drop([0,1,2]).reset_index(drop=True)
        table=table.ix[:,(~pd.isnull(table.columns))] #removing extra nan columns
        states, stateTable=splitbyStateNull(table)#getting states and tables for each state
        stateDictAge=dict(zip(states[0:52],stateTable[0:52]))#making a dictionary for them
    elif year==2010:
        table.ix[1, table.columns[1]]=table.ix[2, table.columns[1]]#dealing with nan entry
        changeCol=dict(zip(table.columns, table.ix[1,:]))#change the columns to match what we want them to be #this portion also not analgous for years
        table.rename(columns=changeCol, inplace=True)
        table=table.drop([0,1]).reset_index(drop=True)
        table=table.ix[:,(~pd.isnull(table.columns))] #removing extra nan columns
        states, stateTable=splitbyStateNull(table) 
        for i in range(len(stateDictAge.keys())):#modifying the dictionary to include this year
            existinglist=stateDictAge[states[i]]
            existinglist=[existinglist, stateTable[i]]
            stateDictAge[states[i]]=existinglist
    elif (year==2008)|(year==2006)|(year==2004):
        table.ix[4,table.columns[0:3]]=table.ix[3,table.columns[0:3]]
        changeCol=dict(zip(table.columns, table.ix[4,:]))#change the columns to match what we want them to be #this portion also not analgous for years
        table.rename(columns=changeCol, inplace=True)
        table=table.drop([0,1,2,3,4]).reset_index(drop=True)#ditto this part
        table=table.ix[:,(~pd.isnull(table.columns))]#removes null columns
        table=table[~pd.isnull(table[table.columns[0]])]#removes null rows
        table.ix[0, table.columns[0]]='US'#one entry header not the same as previous years
        states, stateTable=splitbyStateDot(table)
        splitStates=[item.split(' ') for item in states]#removing random 2s in this year's table
        states=[' '.join([i for i in item if not i.isdigit()]) for item in splitStates]
        for i in range(len(stateDictAge.keys())):#modifying the dictionary again
            existinglist=stateDictAge[states[i]]
            existinglist.append(stateTable[i])
            stateDictRace[states[i]]=existinglist
    if year==2006:
        print 'I could not find data for 2006, so this is 2004 instead.'
    if year==2004:
        print 'Similarly, 2004 is actually 2002.'
# Out:
# I could not find data for 2006, so this is 2004 instead.
# Similarly, 2004 is actually 2002.

# %% [markdown]
# Everything below this point is *only for debugging* - don't worry if it doesn't work.

# %%
#Meena comment: What does confidence interval mean?
#Meena comment: What does the 4 mean?
#Kate comment: the 4 is the fourth entry in the dictionary - each key is a state, and it cooresponds to a *list* of tables
#, where each table is the entry for one year. The fourth entry is the fourth year under study, in this case 2004 I think
stateDictAge['ARKANSAS'][4]
# Out:
#         STATE Population 18 and over Total citizen Percent citizen  \
# 28   ARKANSAS                    NaN           NaN             NaN
# 29     .Total                  1,960         1,919            98.0
# 30  .18 to 24                    223           206            92.4
# 31  .25 to 44                    688           667            96.9
# 32  .45 to 64                    647           645            99.7
# 33  .65 to 74                    206           206           100.0
# 34       .75+                    196           196           100.0
#
#    Confidence interval Total   Percent registered (18+) Confidence interval  \
# 28                 NaN     NaN                      NaN                 NaN
# 29                 0.7   1,222                     62.4                 2.5
# 30                 4.0      71                     31.8                 7.1
# 31                 1.5     391                     56.8                 4.3
# 32                 0.5     443                     68.5                 4.1
# 33                   -     164                     79.4                 6.4
# 34                   -     154                     78.6                 6.6
#
#    Total   Percent voted (18+) Confidence interval
# 28     NaN                 NaN                 NaN
# 29     888                45.3                 2.5
# 30      29                13.0                 5.1
# 31     260                37.8                 4.2
# 32     358                55.3                 4.4
# 33     135                65.4                 7.5
# 34     106                54.2                 8.0

# %%
#Meena comment: get rid of the dots before ".18 to 24" etc.
#Kate comment: is this really necessary? If so you can probably so something like
def removeDot(item):
    item=item.split('.')
    item=item[1:len(item)]
    return item[0]
removeDot('.Stuff')
# Out:
# 'Stuff'

# %%
# Out:
# ['Stuff']

# %%
#Modify table
changeCol=dict(zip(table.columns, table.ix[2,:]))#change the columns to match what we want them to be #this portion also not analgous for years
table.rename(columns=changeCol, inplace=True)
table=table.drop([0,1,2]).reset_index(drop=True)#ditto this part
table=table.ix[:,(~pd.isnull(table.columns))] #removing extra nan columns

# %%
table
# Out:
#                                              .18 to 24  27,377  24,335   88.9  \
# 0                                            .25 to 44  82,228  72,094   87.7
# 1                                            .45 to 64  66,924  63,272   94.5
# 2                                            .65 to 74  17,967  17,415   96.9
# 3                                                 .75+  15,925  15,540   97.6
# 4                                              ALABAMA     NaN     NaN    NaN
# 5                                               .Total   3,252   3,215   98.9
# 6                                            .18 to 24     396     385   97.3
# 7                                            .25 to 44   1,209   1,192   98.6
# 8                                            .45 to 64   1,115   1,108   99.3
# 9                                            .65 to 74     291     290   99.4
# 10                                                .75+     241     241  100.0
# 11                                              ALASKA     NaN            NaN
# 12                                              .Total     437     418   95.7
# 13                                           .18 to 24      56      51    (B)
# 14                                           .25 to 44     180     171   95.3
# 15                                           .45 to 64     162     157   97.0
# 16                                           .65 to 74      25      24    (B)
# 17                                                .75+      13      13    (B)
# 18                                             ARIZONA     NaN     NaN    NaN
# 19                                              .Total   3,800   3,293   86.6
# 20                                           .18 to 24     545     439   80.6
# 21                                           .25 to 44   1,599   1,314   82.2
# 22                                           .45 to 64   1,080     987   91.4
# 23                                           .65 to 74     288     269   93.5
# 24                                                .75+     288     283   98.2
# 25                                            ARKANSAS     NaN     NaN    NaN
# 26                                              .Total   1,960   1,919   98.0
# 27                                           .18 to 24     223     206   92.4
# 28                                           .25 to 44     688     667   96.9
# 29                                           .45 to 64     647     645   99.7
# ..                                                 ...     ...     ...    ...
# 336                                          .25 to 44   1,735   1,537   88.5
# 337                                          .45 to 64   1,492   1,442   96.7
# 338                                          .65 to 74     296     272   91.8
# 339                                               .75+     374     364   97.3
# 340                                      WEST VIRGINIA     NaN     NaN    NaN
# 341                                             .Total   1,379   1,372   99.5
# 342                                          .18 to 24     161     161  100.0
# 343                                          .25 to 44     464     459   98.9
# 344                                          .45 to 64     507     506   99.7
# 345                                          .65 to 74     138     138  100.0
# 346                                               .75+     109     109  100.0
# 347                                          WISCONSIN     NaN     NaN    NaN
# 348                                             .Total   4,119   3,975   96.5
# 349                                          .18 to 24     484     459   94.9
# 350                                          .25 to 44   1,604   1,514   94.4
# 351                                          .45 to 64   1,435   1,405   98.0
# 352                                          .65 to 74     321     321  100.0
# 353                                               .75+     275     275  100.0
# 354                                            WYOMING     NaN     NaN    NaN
# 355                                             .Total     370     368   99.5
# 356                                          .18 to 24      49      49    (B)
# 357                                          .25 to 44     127     126   99.3
# 358                                          .45 to 64     136     135   99.4
# 359                                          .65 to 74      32      32    (B)
# 360                                               .75+      27      26    (B)
# 361                                         Footnotes:     NaN     NaN    NaN
# 362  Note: The symbol (B) means that the base is to...     NaN     NaN    NaN
# 363           " - " Represents zero or rounds to zero.     NaN     NaN    NaN
# 364  Source: U.S. Census Bureau, Current Population...     NaN     NaN    NaN
# 365              Internet Release date:  July 28, 2004     NaN     NaN    NaN
#
#      0.6   4,697  38.2  0.6   4,697  17.2  0.6
# 0    0.3  45,553  55.4  0.5  28,019  34.1  0.5
# 1    0.2  46,430  69.4  0.5  35,521  53.1  0.5
# 2    0.4  13,681  76.1  0.9  11,339  63.1  1.0
# 3    0.3  12,020  75.5  1.0   9,328  58.6  1.1
# 4    NaN     NaN   NaN  NaN     NaN   NaN  NaN
# 5    0.5   2,347  72.2  2.2   1,585  48.7  2.4
# 6    2.2     205  51.8  6.9     102  25.7  6.0
# 7    0.9     846  70.0  3.6     559  46.2  3.9
# 8    0.7     849  76.2  3.5     626  56.1  4.1
# 9    1.2     248  85.0  5.7     174  59.7  7.9
# 10     -     199  82.6  6.7     124  51.6  8.8
# 11   NaN     NaN   NaN  NaN     NaN   NaN  NaN
# 12   1.0     303  69.4  2.2     230  52.6  2.3
# 13   (B)      24   (B)  (B)      14   (B)  (B)
# 14   1.5     119  66.2  3.4      79  44.0  3.6
# 15   1.3     133  81.7  3.0     112  69.2  3.5
# 16   (B)      16   (B)  (B)      15   (B)  (B)
# 17   (B)      10   (B)  (B)       8   (B)  (B)
# 18   NaN     NaN   NaN  NaN     NaN   NaN  NaN
# 19   1.7   1,930  50.8  2.5   1,397  36.8  2.4
# 20   5.1     129  23.6  5.5      48   8.9  3.7
# 21   2.9     693  43.3  3.8     445  27.8  3.4
# 22   2.6     674  62.3  4.5     530  49.1  4.6
# 23   4.4     208  72.4  8.0     186  64.7  8.5
# 24   2.4     227  78.7  7.3     188  65.1  8.5
# 25   NaN     NaN   NaN  NaN     NaN   NaN  NaN
# 26   0.7   1,222  62.4  2.5     888  45.3  2.5
# 27   4.0      71  31.8  7.1      29  13.0  5.1
# 28   1.5     391  56.8  4.3     260  37.8  4.2
# 29   0.5     443  68.5  4.1     358  55.3  4.4
# ..   ...     ...   ...  ...     ...   ...  ...
# 336  2.3   1,014  58.4  3.5     585  33.7  3.4
# 337  1.4   1,159  77.7  3.2     975  65.4  3.7
# 338  4.8     193  65.2  8.2     177  59.9  8.5
# 339  2.5     312  83.6  5.7     275  73.5  6.8
# 340  NaN     NaN   NaN  NaN     NaN   NaN  NaN
# 341  0.3     827  60.0  2.2     507  36.8  2.1
# 342    -      67  41.5  6.4      21  13.1  4.4
# 343  0.8     243  52.4  3.8     125  27.0  3.4
# 344  0.4     346  68.2  3.4     239  47.1  3.6
# 345    -      98  71.3  6.3      73  53.0  7.0
# 346    -      73  67.4  7.4      49  44.7  7.8
# 347  NaN     NaN   NaN  NaN     NaN   NaN  NaN
# 348  0.7   2,744  66.6  1.9   1,999  48.5  2.0
# 349  2.5     200  41.3  5.7      98  20.3  4.7
# 350  1.5     964  60.1  3.1     615  38.3  3.1
# 351  1.0   1,107  77.2  2.8     875  61.0  3.3
# 352    -     252  78.5  5.9     231  71.9  6.4
# 353    -     221  80.4  6.1     180  65.6  7.3
# 354  NaN     NaN   NaN  NaN     NaN   NaN  NaN
# 355  0.3     240  64.9  2.2     198  53.6  2.3
# 356  (B)      20   (B)  (B)      14   (B)  (B)
# 357  0.6      75  58.7  3.9      56  44.4  3.9
# 358  0.6      99  73.0  3.4      86  63.4  3.7
# 359  (B)      24   (B)  (B)      23   (B)  (B)
# 360  (B)      22   (B)  (B)      19   (B)  (B)
# 361  NaN     NaN   NaN  NaN     NaN   NaN  NaN
# 362  NaN     NaN   NaN  NaN     NaN   NaN  NaN
# 363  NaN     NaN   NaN  NaN     NaN   NaN  NaN
# 364  NaN     NaN   NaN  NaN     NaN   NaN  NaN
# 365  NaN     NaN   NaN  NaN     NaN   NaN  NaN
#
# [366 rows x 11 columns]

# %%
#Meena comment: ERROR message - What is stateDict

#Note: I found how many non-nan entries there were with (~pd.isnull(table['State'])).sum() 
for item in stateDict.keys():
    if len(stateDict[item])<5:
        print item
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-61-189be930e715> in <module>()
#       1 #Note: I found how many non-nan entries there were with (~pd.isnull(table['State'])).sum()
# ----> 2 for item in stateDict.keys():
#       3     if len(stateDict[item])<5:
#       4         print item
#
# NameError: name 'stateDict' is not defined

# %%
#Meena comment: What is table2002?
table2002

# %%
count=0
for i in range(52):
    print table2002.ix[10*i,0], count
    count=count+1

# %%
table[table.columns[0]][0:(len(table)-5)]

# %%
indices=pd.DataFrame([item[0]=='.' for item in table[table.columns[0]][0:(len(table)-5)]])#trying to find states automatically
indices=indices.append([False, False, False, False, False]).reset_index(drop=True)
firstcol=table[table.columns[0]]
statesLoc=firstcol[indices[0]==False].index
[item for item in firstcol[indices[0]==False]]
[table.ix[statesLoc[i]:(statesLoc[i+1]-1), :] for i in range(len(statesLoc)-1)]

# %%
item

# %%
count=0
countlast=0
for item in table[table.columns[0]]:
    if item[0]!='.':
        print item
        print count, count-countlast
        countlast=count
    count=count+1

# %%
table2004[30:60]

# %%
table2008.ix[4,table2008.columns[0:3]]=table2008.ix[3,table2008.columns[0:3]]

# %%
table2006

# %%
table2012
table2010
table2008
table2006
table2004
